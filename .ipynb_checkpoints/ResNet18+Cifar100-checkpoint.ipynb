# %% [markdown]
# # Result for **ResNet18+Cifar100**
# ### This notebook is for seed $42$. The results in the paper are the average of $5$ times with seeds in $[1, 19, 31, 42, 80]$

# %% [markdown]
# ## Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Subset

import os
import random
import numpy as np
import pandas as pd
import copy

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: dlopen(/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN2at4_ops19empty_memory_format4callEN3c108ArrayRefINS2_6SymIntEEENS2_8optionalINS2_10ScalarTypeEEENS6_INS2_6LayoutEEENS6_INS2_6DeviceEEENS6_IbEENS6_INS2_12MemoryFormatEEE
#   Referenced from: /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torchvision/image.so
#   Expected in: /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/lib/libtorch_cpu.dylib
#   warn(f"Failed to load image Python extension: {e}")

# %% [markdown]
# ## Models

# %%
"""resnet in pytorch
[1] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun.
    Deep Residual Learning for Image Recognition
    https://arxiv.org/abs/1512.03385v1
"""
class BasicBlock(nn.Module):
    """Basic Block for resnet 18 and resnet 34
    """
    expansion = 1
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()

        self.residual_function = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels * BasicBlock.expansion, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels * BasicBlock.expansion)
        )
        self.shortcut = nn.Sequential()

        if stride != 1 or in_channels != BasicBlock.expansion * out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels * BasicBlock.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels * BasicBlock.expansion)
            )
    def forward(self, x):
        return nn.ReLU(inplace=True)(self.residual_function(x) + self.shortcut(x))


class BottleNeck(nn.Module):
    """Residual block for resnet over 50 layers
    """
    expansion = 4

    def __init__(self, in_channels, out_channels, stride=1):
        super(BottleNeck, self).__init__()
        self.residual_function = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, stride=stride, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels * BottleNeck.expansion, kernel_size=1, bias=False),
            nn.BatchNorm2d(out_channels * BottleNeck.expansion),
        )
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels * BottleNeck.expansion:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels * BottleNeck.expansion, stride=stride, kernel_size=1, bias=False),
                nn.BatchNorm2d(out_channels * BottleNeck.expansion)
            )
    def forward(self, x):
        return nn.ReLU(inplace=True)(self.residual_function(x) + self.shortcut(x))


class ResNet(nn.Module):
    def __init__(self, block, num_block, num_classes=100):
        super(ResNet, self).__init__()
        self.in_channels = 64
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True))
        self.conv2_x = self._make_layer(block, 64, num_block[0], 1)
        self.conv3_x = self._make_layer(block, 128, num_block[1], 2)
        self.conv4_x = self._make_layer(block, 256, num_block[2], 2)
        self.conv5_x = self._make_layer(block, 512, num_block[3], 2)
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(512 * block.expansion, num_classes)
    def _make_layer(self, block, out_channels, num_blocks, stride):
        """make resnet layers(by layer i didnt mean this 'layer' was the
        same as a neuron netowork layer, ex. conv layer), one layer may
        contain more than one residual block
        Args:
            block: block type, basic block or bottle neck block
            out_channels: output depth channel number of this layer
            num_blocks: how many blocks per layer
            stride: the stride of the first block of this layer
        Return:
            return a resnet layer
        """
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels * block.expansion
        return nn.Sequential(*layers)
    def forward(self, x):
        output = self.conv1(x)
        output = self.conv2_x(output)
        output = self.conv3_x(output)
        output = self.conv4_x(output)
        output = self.conv5_x(output)
        output = self.avg_pool(output)
        output = output.view(output.size(0), -1)
        output = self.fc(output)
        return output


def resnet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def resnet18_copy():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %% [markdown]
# ## Prepare data

# %%
def create_loaders(dataset_name, n_workers, batch_size):
    train_data, test_data = load_data(dataset_name)
    train_loader_workers = dict()
    n = len(train_data)
    
    # preparing iterators for workers
    indices = np.arange(n)
    np.random.shuffle(indices)
    a = np.int64(np.floor(n / n_workers))
    top_ind = a * n_workers
    seq = range(a, top_ind, a)
    split = np.split(indices[:top_ind], seq)
    b = 0
    for ind in split:
        train_loader_workers[b] = DataLoader(Subset(train_data, ind), batch_size=batch_size, shuffle=True)
        b = b + 1
    test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

    return train_loader_workers, test_loader


def load_data(dataset_name):
    if dataset_name == 'mnist':
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.1307,), (0.3081,))
        ])
        train_data = datasets.MNIST(root='./data', train=True,
                                    download=True, transform=transform)
        test_data = datasets.MNIST(root='./data', train=False,
                                   download=True, transform=transform)

    elif dataset_name == 'cifar10':
        transform_train = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
        ])
        transform_test = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
        ])
        train_data = datasets.CIFAR10(root='./data', train=True,
                                      download=True, transform=transform_train)
        test_data = datasets.CIFAR10(root='./data', train=False,
                                     download=True, transform=transform_test)

    elif dataset_name == 'cifar100':
        transform_train = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.RandomRotation(15),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.5070751592371323, 0.48654887331495095, 0.4409178433670343],
                                 std=[0.5070751592371323, 0.48654887331495095, 0.4409178433670343])
        ])
        transform_test = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.5070751592371323, 0.48654887331495095, 0.4409178433670343],
                                 std=[0.5070751592371323, 0.48654887331495095, 0.4409178433670343])
        ])
        train_data = datasets.CIFAR100(root='./data', train=True,
                                       download=True, transform=transform_train)
        test_data = datasets.CIFAR100(root='./data', train=False,
                                      download=True, transform=transform_test)

    else:
        raise ValueError(dataset_name + ' is not known.')

    return train_data, test_data

# %% [markdown]
# ## Parameter and Setup

# %%
# Hyperparameters
RANDOM_SEED = 42
lr = 0.01
BATCH_SIZE = 10
NUM_EPOCHS = 50
NUM_WORKERS = 10
D = 10  # compute thread
h = 0.01  # sparse level 99%

if not os.path.exists('result'):
    os.mkdir('result')
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device: ", DEVICE)
# Out:
# Using device:  cpu

# %% [markdown]
# ## Functions

# %%
def seed_torch(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    
    
def evaluate_accuracy(model, data_iter, device):
    correct_1 = 0.0
    correct_5 = 0.0

    for image, label in data_iter:
        image, label = image.to(device), label.to(device)
        output = model(image)

        _, pred = output.topk(5, 1, largest=True, sorted=True)
        label = label.view(label.size(0), -1).expand_as(pred)
        correct = pred.eq(label).float()

        # compute top 5
        correct_5 += correct[:, :5].sum().item()
        # compute top1
        correct_1 += correct[:, :1].sum().item()

    accuracy_1 = 100. * correct_1 / len(data_iter.dataset)
    accuracy_5 = 100. * correct_5 / len(data_iter.dataset)
    return accuracy_1, accuracy_5


# Top_k sparse
def prep_grad(x):
    x_flat = torch.unsqueeze(x, 0).flatten()
    dim = x.shape
    d = x_flat.shape[0]
    return x_flat, dim, d


def top_k_opt(x, h):
    """
    :param x: vector to sparsify
    :param h: density
    :return: compressed vector
    """
    x, dim, d = prep_grad(x)
    # number of coordinates kept
    r = int(np.maximum(1, np.floor(d * h)))
    # positions of top_k coordinates
    _, ind = torch.topk(torch.abs(x), r)
    mask = torch.zeros_like(x)
    mask[ind] = 1
    t = mask * x
    t = t.reshape(dim)
    return t


def compt(old, new):
    result = 0.0
    for i in range(len(old)):
        result += ((old[i].view(-1) - new[i].view(-1)) ** 2).sum().item()
    return result


def adjust_lr(epoch_input):
    lr_ad, lr_th = 0.01, 0.01
    if epoch_input >= 30:
        lr_ad = 0.001
    if epoch_input > 30:
        lr_th = 0.001
    return lr_ad, lr_th

# %% [markdown]
# tasgs

# %%
print("TASGS  lr:"+str(lr)+"--h:"+str(h)+"--epoch:"+str(NUM_EPOCHS)+"--worker:"+str(NUM_WORKERS))
seed_torch(RANDOM_SEED)
model = resnet18()
model.to(DEVICE)
model_copy = resnet18_copy()
model_copy.to(DEVICE)
loss = nn.CrossEntropyLoss()  # 损失函数

# prepare data
dataset_name = 'cifar100'
train_loader_workers, test_loader = create_loaders(dataset_name, NUM_WORKERS, BATCH_SIZE)

NUM_PARAS = sum([1 for param in model.parameters()])
print("Number_parameter:", NUM_PARAS)
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Element_parameter:", total_params)
total_params_sparse = 0
for p in model.parameters():
    x, dim, d = prep_grad(p)
    r = int(np.maximum(1, np.floor(d * h)))
    total_params_sparse += r
print("Element_parameter_sparse:", total_params_sparse)

state_dict = [0 for col in range(NUM_WORKERS)]
grad_worker = [[0 for col in range(NUM_PARAS)] for row in range(NUM_WORKERS)]
grad_gtworker = [[0 for col in range(NUM_PARAS)] for row in range(NUM_WORKERS)]#col是列，row是行  新加的！！！！
error_worker = [[0 for col in range(NUM_PARAS)] for row in range(NUM_WORKERS)]
error_gtworker = [[0 for col in range(NUM_PARAS)] for row in range(NUM_WORKERS)]# 新加的！！！！
grad_old = [0 for col in range(NUM_PARAS)]
grad_new = [0 for col in range(NUM_PARAS)]
para_store = [0 for col in range(NUM_PARAS)]
tau = [0 for col in range(NUM_WORKERS)]
para_list = []
Skip_epoch = []
Loss_epoch = []
train_acc_epoch = []
test_acc_epoch = []

Skip_iter = []
Loss_iter = []
train_acc_iter = []
test_acc_iter = []

iter_num = 0
skip_iter = 0
flag_acc = False

for epoch in range(NUM_EPOCHS):
    train_l_sum, train_acc_sum, num = 0.0, 0.0, 0
    train_loader_iter = [iter(train_loader_workers[w]) for w in range(NUM_WORKERS)]
    iter_steps = len(train_loader_workers[0])
    skip_num = [[0 for col in range(iter_steps)] for row in range(NUM_EPOCHS)]

    # adjust learning_rate
    lr, lr_thead = adjust_lr(epoch)
    print("EPOCH: ", epoch + 1, "learning rate: ", lr)

    for batch_idx in range(iter_steps):
        model.train()
        model_copy.train()
        grad_agg = [0 for col in range(NUM_PARAS)]
        grad_gtagg = [0 for col in range(NUM_PARAS)]#新加的！！！！！
        skip_idx = 0
        if (epoch * iter_steps + batch_idx) < D:
            for w_id in range(NUM_WORKERS):
                images, labels = next(train_loader_iter[w_id])
                images, labels = images.to(DEVICE), labels.to(DEVICE)
                y_hat = model(images)
                Loss = loss(y_hat, labels)
                Loss.backward()
                with torch.no_grad():
                    p_id = 0
                    for p in model.parameters():
                        g = lr * p.grad.data.clone().detach() + error_gtworker[w_id][p_id]
                        Tk_sparse = top_k_opt(g, h)
                        grad_agg[p_id] += Tk_sparse
                        error_worker[w_id][p_id] = g - Tk_sparse
                        grad_worker[w_id][p_id] = Tk_sparse
                        GTk_sparse = top_k_opt(grad_worker[w_id][p_id], h)#111111
                        grad_gtagg[p_id] += GTk_sparse#11111111
                        error_gtworker[w_id][p_id] = error_worker[w_id][p_id] + (Tk_sparse - GTk_sparse)#1111111
                        grad_gtworker[w_id][p_id] = GTk_sparse#1111111
                        p_id += 1
                        p.grad.zero_()

                state_dict[w_id] = copy.deepcopy(model.state_dict())
                train_l_sum += Loss.item()
                train_acc_sum += (y_hat.argmax(dim=1) == labels).sum().item()
                num += labels.shape[0]
        else:
            thread = 0.0
            with torch.no_grad():
                for i in range(len(para_list) - 1):
                    thread += compt(para_list[i], para_list[i + 1])
            thread = thread / (lr_thead * (NUM_WORKERS ** 2))
            for w_id in range(NUM_WORKERS):
                images, labels = next(train_loader_iter[w_id])
                images, labels = images.to(DEVICE), labels.to(DEVICE)
                model_copy.load_state_dict(state_dict[w_id])
                y_copy = model_copy(images)
                Loss_copy = loss(y_copy, labels)
                Loss_copy.backward()
                y_hat = model(images)
                Loss = loss(y_hat, labels)
                Loss.backward()
                with torch.no_grad():
                    p_old_id = 0
                    grad_gtagg = [0 for col in range(NUM_PARAS)]#新加的！！！！！
                    for p_old in model_copy.parameters():
                        grad_old[p_old_id] = p_old.grad.data.clone().detach()
                        p_old_id += 1
                        p_old.grad.zero_()
                    p_id = 0
                    for p in model.parameters():
                        grad_new[p_id] = p.grad.data.clone().detach()
                        p_id += 1
                    if compt(grad_old, grad_new) > 1.25 * thread or tau[w_id] > D:
                        tau[w_id] = 1
                        p_id = 0
                        for p in model.parameters():
                            g = lr * p.grad.data.clone().detach() + error_gtworker[w_id][p_id]
                            Tk_sparse = top_k_opt(g, h)
                            grad_agg[p_id] += Tk_sparse
                            error_worker[w_id][p_id] = g - Tk_sparse
                            grad_worker[w_id][p_id] = Tk_sparse
                            GTk_sparse = top_k_opt(grad_worker[w_id][p_id], h)#1111112
                            grad_gtagg[p_id] += GTk_sparse#111111112
                            error_gtworker[w_id][p_id] = error_worker[w_id][p_id] + (Tk_sparse - GTk_sparse)#11111112
                            grad_gtworker[w_id][p_id] = GTk_sparse#11111112
                            p_id += 1
                            p.grad.zero_()
                        state_dict[w_id] = copy.deepcopy(model.state_dict())
                    else:
                        skip_idx += 1
                        tau[w_id] += 1
                        p_id = 0
                        for p in model.parameters():
                            grad_agg[p_id] += grad_worker[w_id][p_id]
                            grad_gtagg[p_id] += grad_gtworker[w_id][p_id]#11111111
                            p_id += 1
                            p.grad.zero_()
                train_l_sum += Loss.item()
                train_acc_sum += (y_hat.argmax(dim=1) == labels).sum().item()
                num += labels.shape[0]
        skip_num[epoch][batch_idx] = skip_idx
        with torch.no_grad():
            p_id = 0
            for p in model.parameters():
                p.data.add_(grad_gtagg[p_id], alpha=-1)
                para_store[p_id] = p.data.clone().detach()
                p_id += 1
                p.grad.zero_()
            para_list.insert(0, para_store.copy())
            if len(para_list) > D:
                para_list.pop()
        # LOGGING
        if not (batch_idx + 1) % 100:
            print('Epoch: %03d/%03d | Batch %04d/%04d | Cost: %.4f'
                % (epoch + 1, NUM_EPOCHS, batch_idx + 1, len(train_loader_workers[0]), Loss.item()))
        iter_num += 1
        skip_iter += skip_idx
        if not iter_num % 100:
            model.eval()
            with torch.no_grad():
                _, test_acc_it = evaluate_accuracy(model, test_loader, DEVICE)
                Skip_iter.append(skip_iter)
                Loss_iter.append(train_l_sum / (num / BATCH_SIZE))
                train_acc_iter.append(train_acc_sum / num * 100)
                test_acc_iter.append(test_acc_it)
            if test_acc_it > 92.0 and not flag_acc:
                flag_acc = True
                print("*" * 100)
                print("Iter_num:", iter_num, "Test_acc", test_acc_it, "Skip_round:", skip_iter, "Comm_round:", iter_num * 10 - skip_iter)  # 10 workers
                print("*" * 100)
    model.eval()
    with torch.no_grad():
        test_acc_1, test_acc_5 = evaluate_accuracy(model, test_loader, DEVICE)
        Skip_epoch.append(sum(skip_num[epoch]))
        Loss_epoch.append(train_l_sum / (num / BATCH_SIZE))
        train_acc_epoch.append(train_acc_sum / num * 100)
        test_acc_epoch.append(test_acc_5)
    print('epoch %d, skip_num %d, loss %.4f, train acc %.3f%%, top_1 test acc %.3f%%, top_5 test acc %.3f%%'
        % (epoch + 1, Skip_epoch[epoch], train_l_sum / (num / BATCH_SIZE), train_acc_sum / num * 100, test_acc_1, test_acc_5))

print('Finished.')

list_write = []
list_write.append(Skip_epoch)
list_write.append(Loss_epoch)
list_write.append(train_acc_epoch)
list_write.append(test_acc_epoch)
name = ['Skip', 'Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name, data=list_write).T
test.to_csv("./result/"+"TASGS-res-cifar100.csv", encoding='gbk')


list_write_iter = []
list_write_iter.append(Skip_iter)
list_write_iter.append(Loss_iter)
list_write_iter.append(train_acc_iter)
list_write_iter.append(test_acc_iter)
name_iter = ['Skip', 'Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name_iter, data=list_write_iter).T
test.to_csv("./result/"+"TASGS-res-cifar100-iter.csv", encoding='gbk')
# Out:
# TASGS  lr:0.01--h:0.01--epoch:50--worker:10
# Number_parameter: 62
# Element_parameter: 11220132
# Element_parameter_sparse: 112184
# EPOCH:  1 learning rate:  0.01
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 68
#      66 images, labels = next(train_loader_iter[w_id])
#      67 images, labels = images.to(DEVICE), labels.to(DEVICE)
# ---> 68 y_hat = model(images)
#      69 Loss = loss(y_hat, labels)
#      70 Loss.backward()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[2], line 91, in ResNet.forward(self, x)
#      90 def forward(self, x):
# ---> 91     output = self.conv1(x)
#      92     output = self.conv2_x(output)
#      93     output = self.conv3_x(output)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/nn/modules/container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/nn/modules/conv.py:457, in Conv2d.forward(self, input)
#     456 def forward(self, input: Tensor) -> Tensor:
# --> 457     return self._conv_forward(input, self.weight, self.bias)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/torch/nn/modules/conv.py:453, in Conv2d._conv_forward(self, input, weight, bias)
#     449 if self.padding_mode != 'zeros':
#     450     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     451                     weight, bias, self.stride,
#     452                     _pair(0), self.dilation, self.groups)
# --> 453 return F.conv2d(input, weight, bias, self.stride,
#     454                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Given groups=1, weight of size [64, 3, 3, 3], expected input[10, 1, 28, 28] to have 3 channels, but got 1 channels instead

# %% [markdown]
# # SASG

# %%
print("SASG  lr:"+str(lr)+"--h:"+str(h)+"--epoch:"+str(NUM_EPOCHS)+"--worker:"+str(NUM_WORKERS))
seed_torch(RANDOM_SEED)
model = resnet18()
model.to(DEVICE)
model_copy = resnet18_copy()
model_copy.to(DEVICE)
loss = nn.CrossEntropyLoss()  # 损失函数

# prepare data
dataset_name = 'cifar100'
train_loader_workers, test_loader = create_loaders(dataset_name, NUM_WORKERS, BATCH_SIZE)

NUM_PARAS = sum([1 for param in model.parameters()])
print("Number_parameter:", NUM_PARAS)
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Element_parameter:", total_params)
total_params_sparse = 0
for p in model.parameters():
    x, dim, d = prep_grad(p)
    r = int(np.maximum(1, np.floor(d * h)))
    total_params_sparse += r
print("Element_parameter_sparse:", total_params_sparse)

state_dict = [0 for col in range(NUM_WORKERS)]
grad_worker = [[0 for col in range(NUM_PARAS)] for row in range(NUM_WORKERS)]
error_worker = [[0 for col in range(NUM_PARAS)] for row in range(NUM_WORKERS)]
grad_old = [0 for col in range(NUM_PARAS)]
grad_new = [0 for col in range(NUM_PARAS)]
para_store = [0 for col in range(NUM_PARAS)]
tau = [0 for col in range(NUM_WORKERS)]
para_list = []
Skip_epoch = []
Loss_epoch = []
train_acc_epoch = []
test_acc_epoch = []

Skip_iter = []
Loss_iter = []
train_acc_iter = []
test_acc_iter = []

iter_num = 0
skip_iter = 0
flag_acc = False

for epoch in range(NUM_EPOCHS):
    train_l_sum, train_acc_sum, num = 0.0, 0.0, 0
    train_loader_iter = [iter(train_loader_workers[w]) for w in range(NUM_WORKERS)]
    iter_steps = len(train_loader_workers[0])
    skip_num = [[0 for col in range(iter_steps)] for row in range(NUM_EPOCHS)]

    # adjust learning_rate
    lr, lr_thead = adjust_lr(epoch)
    print("EPOCH: ", epoch + 1, "learning rate: ", lr)

    for batch_idx in range(iter_steps):
        model.train()
        model_copy.train()
        grad_agg = [0 for col in range(NUM_PARAS)]
        skip_idx = 0
        if (epoch * iter_steps + batch_idx) < D:
            for w_id in range(NUM_WORKERS):
                images, labels = next(train_loader_iter[w_id])
                images, labels = images.to(DEVICE), labels.to(DEVICE)
                y_hat = model(images)
                Loss = loss(y_hat, labels)
                Loss.backward()
                with torch.no_grad():
                    p_id = 0
                    for p in model.parameters():
                        g = lr * p.grad.data.clone().detach() + error_worker[w_id][p_id]
                        Tk_sparse = top_k_opt(g, h)
                        grad_agg[p_id] += Tk_sparse
                        error_worker[w_id][p_id] = g - Tk_sparse
                        grad_worker[w_id][p_id] = Tk_sparse
                        p_id += 1
                        p.grad.zero_()

                state_dict[w_id] = copy.deepcopy(model.state_dict())
                train_l_sum += Loss.item()
                train_acc_sum += (y_hat.argmax(dim=1) == labels).sum().item()
                num += labels.shape[0]
        else:
            thread = 0.0
            with torch.no_grad():
                for i in range(len(para_list) - 1):
                    thread += compt(para_list[i], para_list[i + 1])
            thread = thread / (lr_thead * (NUM_WORKERS ** 2))
            for w_id in range(NUM_WORKERS):
                images, labels = next(train_loader_iter[w_id])
                images, labels = images.to(DEVICE), labels.to(DEVICE)
                model_copy.load_state_dict(state_dict[w_id])
                y_copy = model_copy(images)
                Loss_copy = loss(y_copy, labels)
                Loss_copy.backward()
                y_hat = model(images)
                Loss = loss(y_hat, labels)
                Loss.backward()
                with torch.no_grad():
                    p_old_id = 0
                    for p_old in model_copy.parameters():
                        grad_old[p_old_id] = p_old.grad.data.clone().detach()
                        p_old_id += 1
                        p_old.grad.zero_()
                    p_id = 0
                    for p in model.parameters():
                        grad_new[p_id] = p.grad.data.clone().detach()
                        p_id += 1
                    if compt(grad_old, grad_new) > 1.25 * thread or tau[w_id] > D:
                        tau[w_id] = 1
                        p_id = 0
                        for p in model.parameters():
                            g = lr * p.grad.data.clone().detach() + error_worker[w_id][p_id]
                            Tk_sparse = top_k_opt(g, h)
                            grad_agg[p_id] += Tk_sparse
                            error_worker[w_id][p_id] = g - Tk_sparse
                            grad_worker[w_id][p_id] = Tk_sparse
                            p_id += 1
                            p.grad.zero_()
                        state_dict[w_id] = copy.deepcopy(model.state_dict())
                    else:
                        skip_idx += 1
                        tau[w_id] += 1
                        p_id = 0
                        for p in model.parameters():
                            grad_agg[p_id] += grad_worker[w_id][p_id]
                            p_id += 1
                            p.grad.zero_()
                train_l_sum += Loss.item()
                train_acc_sum += (y_hat.argmax(dim=1) == labels).sum().item()
                num += labels.shape[0]
        skip_num[epoch][batch_idx] = skip_idx
        with torch.no_grad():
            p_id = 0
            for p in model.parameters():
                p.data.add_(grad_agg[p_id], alpha=-1)
                para_store[p_id] = p.data.clone().detach()
                p_id += 1
                p.grad.zero_()
            para_list.insert(0, para_store.copy())
            if len(para_list) > D:
                para_list.pop()
        # LOGGING
        if not (batch_idx + 1) % 100:
            print('Epoch: %03d/%03d | Batch %04d/%04d | Cost: %.4f'
                % (epoch + 1, NUM_EPOCHS, batch_idx + 1, len(train_loader_workers[0]), Loss.item()))
        iter_num += 1
        skip_iter += skip_idx
        if not iter_num % 100:
            model.eval()
            with torch.no_grad():
                _, test_acc_it = evaluate_accuracy(model, test_loader, DEVICE)
                Skip_iter.append(skip_iter)
                Loss_iter.append(train_l_sum / (num / BATCH_SIZE))
                train_acc_iter.append(train_acc_sum / num * 100)
                test_acc_iter.append(test_acc_it)
            if test_acc_it > 92.0 and not flag_acc:
                flag_acc = True
                print("*" * 100)
                print("Iter_num:", iter_num, "Test_acc", test_acc_it, "Skip_round:", skip_iter, "Comm_round:", iter_num * 10 - skip_iter)  # 10 workers
                print("*" * 100)
    model.eval()
    with torch.no_grad():
        test_acc_1, test_acc_5 = evaluate_accuracy(model, test_loader, DEVICE)
        Skip_epoch.append(sum(skip_num[epoch]))
        Loss_epoch.append(train_l_sum / (num / BATCH_SIZE))
        train_acc_epoch.append(train_acc_sum / num * 100)
        test_acc_epoch.append(test_acc_5)
    print('epoch %d, skip_num %d, loss %.4f, train acc %.3f%%, top_1 test acc %.3f%%, top_5 test acc %.3f%%'
        % (epoch + 1, Skip_epoch[epoch], train_l_sum / (num / BATCH_SIZE), train_acc_sum / num * 100, test_acc_1, test_acc_5))

print('Finished.')

list_write = []
list_write.append(Skip_epoch)
list_write.append(Loss_epoch)
list_write.append(train_acc_epoch)
list_write.append(test_acc_epoch)
name = ['Skip', 'Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name, data=list_write).T
test.to_csv("./result/"+"SASG-res-cifar100.csv", encoding='gbk')


list_write_iter = []
list_write_iter.append(Skip_iter)
list_write_iter.append(Loss_iter)
list_write_iter.append(train_acc_iter)
list_write_iter.append(test_acc_iter)
name_iter = ['Skip', 'Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name_iter, data=list_write_iter).T
test.to_csv("./result/"+"SASG-res-cifar100-iter.csv", encoding='gbk')
# Out:
# SASG  lr:0.01--h:0.01--epoch:50--worker:10
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 70.2%

# %% [markdown]
# # LASG

# %%
print("LASG  lr:"+str(lr)+"--epoch:"+str(NUM_EPOCHS)+"--worker:"+str(NUM_WORKERS))
seed_torch(RANDOM_SEED)
model = resnet18()
model.to(DEVICE)
model_copy = resnet18_copy()
model_copy.to(DEVICE)
loss = nn.CrossEntropyLoss()  # 损失函数

# prepare data
dataset_name = 'cifar100'
train_loader_workers, test_loader = create_loaders(dataset_name, NUM_WORKERS, BATCH_SIZE)

NUM_PARAS = sum([1 for param in model.parameters()])
print("Number_parameter:", NUM_PARAS)
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Element_parameter:", total_params)

state_dict = [0 for col in range(NUM_WORKERS)]
grad_worker = [[0 for col in range(NUM_PARAS)] for row in range(NUM_WORKERS)]
grad_old = [0 for col in range(NUM_PARAS)]
grad_new = [0 for col in range(NUM_PARAS)]
para_store = [0 for col in range(NUM_PARAS)]
tau = [0 for col in range(NUM_WORKERS)]
para_list = []
Skip_epoch = []
Loss_epoch = []
train_acc_epoch = []
test_acc_epoch = []

Skip_iter = []
Loss_iter = []
train_acc_iter = []
test_acc_iter = []

iter_num = 0
skip_iter = 0
flag_acc = False

for epoch in range(NUM_EPOCHS):
    train_l_sum, train_acc_sum, num = 0.0, 0.0, 0
    train_loader_iter = [iter(train_loader_workers[w]) for w in range(NUM_WORKERS)]
    iter_steps = len(train_loader_workers[0])
    skip_num = [[0 for col in range(iter_steps)] for row in range(NUM_EPOCHS)]

    # adjust learning_rate
    lr, lr_thead = adjust_lr(epoch)
    print("EPOCH: ", epoch + 1, "learning rate: ", lr)

    for batch_idx in range(iter_steps):
        model.train()
        model_copy.train()
        grad_agg = [0 for col in range(NUM_PARAS)]
        skip_idx = 0
        if (epoch * iter_steps + batch_idx) < D:
            for w_id in range(NUM_WORKERS):
                images, labels = next(train_loader_iter[w_id])
                images, labels = images.to(DEVICE), labels.to(DEVICE)
                y_hat = model(images)
                Loss = loss(y_hat, labels)
                Loss.backward()
                with torch.no_grad():
                    p_id = 0
                    for p in model.parameters():
                        g = lr * p.grad.data.clone().detach()
                        grad_agg[p_id] += g
                        grad_worker[w_id][p_id] = g
                        p_id += 1
                        p.grad.zero_()
                state_dict[w_id] = copy.deepcopy(model.state_dict())
                train_l_sum += Loss.item()
                train_acc_sum += (y_hat.argmax(dim=1) == labels).sum().item()
                num += labels.shape[0]
        else:
            thread = 0.0
            with torch.no_grad():
                for i in range(len(para_list) - 1):
                    thread += compt(para_list[i], para_list[i + 1])
            thread = thread / (lr_thead * (NUM_WORKERS ** 2))
            for w_id in range(NUM_WORKERS):
                images, labels = next(train_loader_iter[w_id])
                images, labels = images.to(DEVICE), labels.to(DEVICE)
                model_copy.load_state_dict(state_dict[w_id])
                y_copy = model_copy(images)
                Loss_copy = loss(y_copy, labels)
                Loss_copy.backward()
                y_hat = model(images)
                Loss = loss(y_hat, labels)
                Loss.backward()
                with torch.no_grad():
                    p_old_id = 0
                    for p_old in model_copy.parameters():
                        grad_old[p_old_id] = p_old.grad.data.clone().detach()
                        p_old_id += 1
                        p_old.grad.zero_()
                    p_id = 0
                    for p in model.parameters():
                        grad_new[p_id] = p.grad.data.clone().detach()
                        p_id += 1
                    if compt(grad_old, grad_new) > 5.0 * thread or tau[w_id] > D:
                        tau[w_id] = 1
                        p_id = 0
                        for p in model.parameters():
                            g = lr * p.grad.data.clone().detach()
                            grad_agg[p_id] += g
                            grad_worker[w_id][p_id] = g
                            p_id += 1
                            p.grad.zero_()
                        state_dict[w_id] = copy.deepcopy(model.state_dict())
                    else:
                        skip_idx += 1
                        tau[w_id] += 1
                        p_id = 0
                        for p in model.parameters():
                            grad_agg[p_id] += grad_worker[w_id][p_id]
                            p_id += 1
                            p.grad.zero_()
                train_l_sum += Loss.item()
                train_acc_sum += (y_hat.argmax(dim=1) == labels).sum().item()
                num += labels.shape[0]
        skip_num[epoch][batch_idx] = skip_idx
        with torch.no_grad():
            p_id = 0
            for p in model.parameters():
                p.data.add_(grad_agg[p_id], alpha=-1)
                para_store[p_id] = p.data.clone().detach()
                p_id += 1
                p.grad.zero_()

            para_list.insert(0, para_store.copy())
            if len(para_list) > D:
                para_list.pop()
        # LOGGING
        if not (batch_idx + 1) % 100:
            print('Epoch: %03d/%03d | Batch %04d/%04d | Cost: %.4f'
                % (epoch + 1, NUM_EPOCHS, batch_idx + 1, len(train_loader_workers[0]), Loss.item()))

        iter_num += 1
        skip_iter += skip_idx
        if not iter_num % 100:
            model.eval()
            with torch.no_grad():
                _, test_acc_it = evaluate_accuracy(model, test_loader, DEVICE)
                Skip_iter.append(skip_iter)
                Loss_iter.append(train_l_sum / (num / BATCH_SIZE))
                train_acc_iter.append(train_acc_sum / num * 100)
                test_acc_iter.append(test_acc_it)
            if test_acc_it > 92.0 and not flag_acc:
                flag_acc = True
                print("*" * 100)
                print("Iter_num:", iter_num, "Test_acc", test_acc_it, "Skip_round:", skip_iter, "Comm_round:",
                    iter_num * 10 - skip_iter)  # 10 workers
                print("*" * 100)
    model.eval()
    with torch.no_grad():
        test_acc_1, test_acc_5 = evaluate_accuracy(model, test_loader, DEVICE)
        Skip_epoch.append(sum(skip_num[epoch]))
        Loss_epoch.append(train_l_sum / (num / BATCH_SIZE))
        train_acc_epoch.append(train_acc_sum / num * 100)
        test_acc_epoch.append(test_acc_5)
    print('epoch %d, skip_num %d, loss %.4f, train acc %.3f%%, top_1 test acc %.3f%%, top_5 test acc %.3f%%'
        % (epoch + 1, Skip_epoch[epoch], train_l_sum / (num / BATCH_SIZE), train_acc_sum / num * 100, test_acc_1, test_acc_5))

print('Finished.')

list_write = []
list_write.append(Skip_epoch)
list_write.append(Loss_epoch)
list_write.append(train_acc_epoch)
list_write.append(test_acc_epoch)
name = ['Skip', 'Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name, data=list_write).T
test.to_csv("./result/"+"LASG-res-cifar100.csv", encoding='gbk')

list_write_iter = []
list_write_iter.append(Skip_iter)
list_write_iter.append(Loss_iter)
list_write_iter.append(train_acc_iter)
list_write_iter.append(test_acc_iter)
name_iter = ['Skip', 'Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name_iter, data=list_write_iter).T
test.to_csv("./result/"+"LASG-res-cifar100-iter.csv", encoding='gbk')
# Out:
# LASG  lr:0.001--epoch:50--worker:10
# Files already downloaded and verified
# Files already downloaded and verified
# Number_parameter: 62
# Element_parameter: 11220132
# EPOCH:  1 learning rate:  0.01
# Epoch: 001/050 | Batch 0100/0500 | Cost: 4.2462
# Epoch: 001/050 | Batch 0200/0500 | Cost: 3.8626
# Epoch: 001/050 | Batch 0300/0500 | Cost: 3.6018
# Epoch: 001/050 | Batch 0400/0500 | Cost: 3.0582
# Epoch: 001/050 | Batch 0500/0500 | Cost: 2.9845
# epoch 1, skip_num 0, loss 3.8238, train acc 11.328%, top_1 test acc 20.090%, top_5 test acc 47.620%
# EPOCH:  2 learning rate:  0.01
# Epoch: 002/050 | Batch 0100/0500 | Cost: 2.8373
# Epoch: 002/050 | Batch 0200/0500 | Cost: 2.8270
# Epoch: 002/050 | Batch 0300/0500 | Cost: 2.9877
# Epoch: 002/050 | Batch 0400/0500 | Cost: 3.4615
# Epoch: 002/050 | Batch 0500/0500 | Cost: 3.2960
# epoch 2, skip_num 0, loss 3.1415, train acc 22.522%, top_1 test acc 31.070%, top_5 test acc 62.590%
# EPOCH:  3 learning rate:  0.01
# Epoch: 003/050 | Batch 0100/0500 | Cost: 2.5796
# Epoch: 003/050 | Batch 0200/0500 | Cost: 2.0863
# Epoch: 003/050 | Batch 0300/0500 | Cost: 2.6173
# Epoch: 003/050 | Batch 0400/0500 | Cost: 2.0860
# Epoch: 003/050 | Batch 0500/0500 | Cost: 3.1867
# epoch 3, skip_num 0, loss 2.7203, train acc 30.572%, top_1 test acc 38.210%, top_5 test acc 68.870%
# EPOCH:  4 learning rate:  0.01
# Epoch: 004/050 | Batch 0100/0500 | Cost: 2.8307
# Epoch: 004/050 | Batch 0200/0500 | Cost: 2.5217
# Epoch: 004/050 | Batch 0300/0500 | Cost: 2.1563
# Epoch: 004/050 | Batch 0400/0500 | Cost: 2.5368
# Epoch: 004/050 | Batch 0500/0500 | Cost: 2.9147
# epoch 4, skip_num 0, loss 2.4159, train acc 36.824%, top_1 test acc 41.690%, top_5 test acc 73.380%
# EPOCH:  5 learning rate:  0.01
# Epoch: 005/050 | Batch 0100/0500 | Cost: 1.5364
# Epoch: 005/050 | Batch 0200/0500 | Cost: 1.8258
# Epoch: 005/050 | Batch 0300/0500 | Cost: 2.8390
# Epoch: 005/050 | Batch 0400/0500 | Cost: 2.0247
# Epoch: 005/050 | Batch 0500/0500 | Cost: 2.1664
# epoch 5, skip_num 0, loss 2.1934, train acc 41.808%, top_1 test acc 46.020%, top_5 test acc 77.280%
# EPOCH:  6 learning rate:  0.01
# Epoch: 006/050 | Batch 0100/0500 | Cost: 2.3355
# Epoch: 006/050 | Batch 0200/0500 | Cost: 2.6139
# Epoch: 006/050 | Batch 0300/0500 | Cost: 1.4802
# Epoch: 006/050 | Batch 0400/0500 | Cost: 2.1350
# Epoch: 006/050 | Batch 0500/0500 | Cost: 2.7539
# epoch 6, skip_num 1, loss 2.0224, train acc 45.480%, top_1 test acc 50.840%, top_5 test acc 81.430%
# EPOCH:  7 learning rate:  0.01
# Epoch: 007/050 | Batch 0100/0500 | Cost: 1.7141
# Epoch: 007/050 | Batch 0200/0500 | Cost: 1.8831
# Epoch: 007/050 | Batch 0300/0500 | Cost: 1.7083
# Epoch: 007/050 | Batch 0400/0500 | Cost: 2.2720
# Epoch: 007/050 | Batch 0500/0500 | Cost: 2.2566
# epoch 7, skip_num 6, loss 1.8819, train acc 49.118%, top_1 test acc 52.620%, top_5 test acc 81.350%
# EPOCH:  8 learning rate:  0.01
# Epoch: 008/050 | Batch 0100/0500 | Cost: 3.4801
# Epoch: 008/050 | Batch 0200/0500 | Cost: 0.7873
# Epoch: 008/050 | Batch 0300/0500 | Cost: 1.6514
# Epoch: 008/050 | Batch 0400/0500 | Cost: 1.5720
# Epoch: 008/050 | Batch 0500/0500 | Cost: 2.1206
# epoch 8, skip_num 15, loss 1.7701, train acc 51.748%, top_1 test acc 56.290%, top_5 test acc 84.400%
# EPOCH:  9 learning rate:  0.01
# Epoch: 009/050 | Batch 0100/0500 | Cost: 1.8716
# Epoch: 009/050 | Batch 0200/0500 | Cost: 2.7556
# Epoch: 009/050 | Batch 0300/0500 | Cost: 1.0501
# Epoch: 009/050 | Batch 0400/0500 | Cost: 1.4249
# Epoch: 009/050 | Batch 0500/0500 | Cost: 2.0486
# epoch 9, skip_num 30, loss 1.6682, train acc 54.018%, top_1 test acc 57.070%, top_5 test acc 84.670%
# EPOCH:  10 learning rate:  0.01
# Epoch: 010/050 | Batch 0100/0500 | Cost: 1.1064
# Epoch: 010/050 | Batch 0200/0500 | Cost: 1.2871
# Epoch: 010/050 | Batch 0300/0500 | Cost: 1.7039
# Epoch: 010/050 | Batch 0400/0500 | Cost: 1.0015
# Epoch: 010/050 | Batch 0500/0500 | Cost: 1.4048
# epoch 10, skip_num 27, loss 1.5850, train acc 55.854%, top_1 test acc 57.470%, top_5 test acc 85.180%
# EPOCH:  11 learning rate:  0.01
# Epoch: 011/050 | Batch 0100/0500 | Cost: 1.0759
# Epoch: 011/050 | Batch 0200/0500 | Cost: 1.0586
# Epoch: 011/050 | Batch 0300/0500 | Cost: 1.8292
# Epoch: 011/050 | Batch 0400/0500 | Cost: 2.3131
# Epoch: 011/050 | Batch 0500/0500 | Cost: 0.7900
# epoch 11, skip_num 53, loss 1.5056, train acc 57.670%, top_1 test acc 60.070%, top_5 test acc 86.910%
# EPOCH:  12 learning rate:  0.01
# Epoch: 012/050 | Batch 0100/0500 | Cost: 1.9592
# Epoch: 012/050 | Batch 0200/0500 | Cost: 1.6129
# Epoch: 012/050 | Batch 0300/0500 | Cost: 2.5782
# Epoch: 012/050 | Batch 0400/0500 | Cost: 1.5187
# Epoch: 012/050 | Batch 0500/0500 | Cost: 0.3391
# epoch 12, skip_num 77, loss 1.4447, train acc 59.266%, top_1 test acc 59.900%, top_5 test acc 87.100%
# EPOCH:  13 learning rate:  0.01
# Epoch: 013/050 | Batch 0100/0500 | Cost: 1.5730
# Epoch: 013/050 | Batch 0200/0500 | Cost: 0.5536
# Epoch: 013/050 | Batch 0300/0500 | Cost: 1.2630
# Epoch: 013/050 | Batch 0400/0500 | Cost: 1.6616
# Epoch: 013/050 | Batch 0500/0500 | Cost: 1.8274
# epoch 13, skip_num 86, loss 1.3781, train acc 60.716%, top_1 test acc 59.470%, top_5 test acc 86.520%
# EPOCH:  14 learning rate:  0.01
# Epoch: 014/050 | Batch 0100/0500 | Cost: 1.6149
# Epoch: 014/050 | Batch 0200/0500 | Cost: 0.9387
# Epoch: 014/050 | Batch 0300/0500 | Cost: 1.8380
# Epoch: 014/050 | Batch 0400/0500 | Cost: 1.4880
# Epoch: 014/050 | Batch 0500/0500 | Cost: 1.0786
# epoch 14, skip_num 104, loss 1.3252, train acc 61.990%, top_1 test acc 60.500%, top_5 test acc 86.890%
# EPOCH:  15 learning rate:  0.01
# Epoch: 015/050 | Batch 0100/0500 | Cost: 1.6467
# Epoch: 015/050 | Batch 0200/0500 | Cost: 2.0165
# Epoch: 015/050 | Batch 0300/0500 | Cost: 2.0125
# Epoch: 015/050 | Batch 0400/0500 | Cost: 2.4590
# Epoch: 015/050 | Batch 0500/0500 | Cost: 0.9587
# epoch 15, skip_num 131, loss 1.2702, train acc 63.534%, top_1 test acc 62.820%, top_5 test acc 88.010%
# EPOCH:  16 learning rate:  0.01
# Epoch: 016/050 | Batch 0100/0500 | Cost: 1.2337
# Epoch: 016/050 | Batch 0200/0500 | Cost: 1.9850
# Epoch: 016/050 | Batch 0300/0500 | Cost: 0.8665
# Epoch: 016/050 | Batch 0400/0500 | Cost: 1.7638
# Epoch: 016/050 | Batch 0500/0500 | Cost: 1.9418
# epoch 16, skip_num 170, loss 1.2245, train acc 64.758%, top_1 test acc 64.170%, top_5 test acc 89.240%
# EPOCH:  17 learning rate:  0.01
# Epoch: 017/050 | Batch 0100/0500 | Cost: 0.9321
# Epoch: 017/050 | Batch 0200/0500 | Cost: 0.9011
# Epoch: 017/050 | Batch 0300/0500 | Cost: 0.8812
# Epoch: 017/050 | Batch 0400/0500 | Cost: 1.1194
# Epoch: 017/050 | Batch 0500/0500 | Cost: 1.1522
# epoch 17, skip_num 201, loss 1.1740, train acc 66.034%, top_1 test acc 64.160%, top_5 test acc 89.330%
# EPOCH:  18 learning rate:  0.01
# Epoch: 018/050 | Batch 0100/0500 | Cost: 1.1934
# Epoch: 018/050 | Batch 0200/0500 | Cost: 1.7535
# Epoch: 018/050 | Batch 0300/0500 | Cost: 0.8286
# Epoch: 018/050 | Batch 0400/0500 | Cost: 1.4692
# Epoch: 018/050 | Batch 0500/0500 | Cost: 1.8194
# epoch 18, skip_num 207, loss 1.1362, train acc 66.816%, top_1 test acc 63.990%, top_5 test acc 88.930%
# EPOCH:  19 learning rate:  0.01
# Epoch: 019/050 | Batch 0100/0500 | Cost: 0.9806
# Epoch: 019/050 | Batch 0200/0500 | Cost: 1.1840
# Epoch: 019/050 | Batch 0300/0500 | Cost: 1.7292
# Epoch: 019/050 | Batch 0400/0500 | Cost: 0.7551
# Epoch: 019/050 | Batch 0500/0500 | Cost: 0.9324
# epoch 19, skip_num 222, loss 1.0929, train acc 67.964%, top_1 test acc 65.690%, top_5 test acc 89.380%
# EPOCH:  20 learning rate:  0.01
# Epoch: 020/050 | Batch 0100/0500 | Cost: 0.3925
# Epoch: 020/050 | Batch 0200/0500 | Cost: 0.1214
# Epoch: 020/050 | Batch 0300/0500 | Cost: 1.6085
# Epoch: 020/050 | Batch 0400/0500 | Cost: 1.6476
# Epoch: 020/050 | Batch 0500/0500 | Cost: 1.3487
# epoch 20, skip_num 281, loss 1.0562, train acc 68.886%, top_1 test acc 65.410%, top_5 test acc 90.100%
# EPOCH:  21 learning rate:  0.01
# Epoch: 021/050 | Batch 0100/0500 | Cost: 0.4148
# Epoch: 021/050 | Batch 0200/0500 | Cost: 1.2343
# Epoch: 021/050 | Batch 0300/0500 | Cost: 0.9627
# Epoch: 021/050 | Batch 0400/0500 | Cost: 1.4152
# Epoch: 021/050 | Batch 0500/0500 | Cost: 1.3952
# epoch 21, skip_num 316, loss 1.0277, train acc 69.560%, top_1 test acc 65.080%, top_5 test acc 89.650%
# EPOCH:  22 learning rate:  0.01
# Epoch: 022/050 | Batch 0100/0500 | Cost: 0.4661
# Epoch: 022/050 | Batch 0200/0500 | Cost: 1.6887
# Epoch: 022/050 | Batch 0300/0500 | Cost: 1.3168
# Epoch: 022/050 | Batch 0400/0500 | Cost: 1.9001
# Epoch: 022/050 | Batch 0500/0500 | Cost: 0.9040
# epoch 22, skip_num 404, loss 0.9919, train acc 70.736%, top_1 test acc 66.920%, top_5 test acc 90.160%
# EPOCH:  23 learning rate:  0.01
# Epoch: 023/050 | Batch 0100/0500 | Cost: 1.0743
# Epoch: 023/050 | Batch 0200/0500 | Cost: 1.0306
# Epoch: 023/050 | Batch 0300/0500 | Cost: 0.9009
# Epoch: 023/050 | Batch 0400/0500 | Cost: 0.5789
# Epoch: 023/050 | Batch 0500/0500 | Cost: 1.0964
# epoch 23, skip_num 414, loss 0.9594, train acc 71.484%, top_1 test acc 65.250%, top_5 test acc 90.020%
# EPOCH:  24 learning rate:  0.01
# Epoch: 024/050 | Batch 0100/0500 | Cost: 0.3430
# Epoch: 024/050 | Batch 0200/0500 | Cost: 0.7707
# Epoch: 024/050 | Batch 0300/0500 | Cost: 0.3367
# Epoch: 024/050 | Batch 0400/0500 | Cost: 1.3355
# Epoch: 024/050 | Batch 0500/0500 | Cost: 0.8058
# epoch 24, skip_num 443, loss 0.9379, train acc 71.872%, top_1 test acc 66.680%, top_5 test acc 90.220%
# EPOCH:  25 learning rate:  0.01
# Epoch: 025/050 | Batch 0100/0500 | Cost: 1.3378
# Epoch: 025/050 | Batch 0200/0500 | Cost: 0.4889
# Epoch: 025/050 | Batch 0300/0500 | Cost: 1.3897
# Epoch: 025/050 | Batch 0400/0500 | Cost: 1.4735
# Epoch: 025/050 | Batch 0500/0500 | Cost: 0.3190
# epoch 25, skip_num 463, loss 0.9099, train acc 72.604%, top_1 test acc 66.610%, top_5 test acc 90.390%
# EPOCH:  26 learning rate:  0.01
# Epoch: 026/050 | Batch 0100/0500 | Cost: 1.1743
# Epoch: 026/050 | Batch 0200/0500 | Cost: 0.7621
# Epoch: 026/050 | Batch 0300/0500 | Cost: 0.4371
# Epoch: 026/050 | Batch 0400/0500 | Cost: 1.1141
# Epoch: 026/050 | Batch 0500/0500 | Cost: 1.3677
# epoch 26, skip_num 495, loss 0.8829, train acc 73.464%, top_1 test acc 67.220%, top_5 test acc 90.730%
# EPOCH:  27 learning rate:  0.01
# Epoch: 027/050 | Batch 0100/0500 | Cost: 0.2584
# Epoch: 027/050 | Batch 0200/0500 | Cost: 0.6086
# Epoch: 027/050 | Batch 0300/0500 | Cost: 0.7854
# Epoch: 027/050 | Batch 0400/0500 | Cost: 0.3445
# Epoch: 027/050 | Batch 0500/0500 | Cost: 0.5777
# epoch 27, skip_num 573, loss 0.8521, train acc 74.594%, top_1 test acc 67.240%, top_5 test acc 90.390%
# EPOCH:  28 learning rate:  0.01
# Epoch: 028/050 | Batch 0100/0500 | Cost: 0.4797
# Epoch: 028/050 | Batch 0200/0500 | Cost: 0.8962
# Epoch: 028/050 | Batch 0300/0500 | Cost: 0.8422
# Epoch: 028/050 | Batch 0400/0500 | Cost: 0.8613
# Epoch: 028/050 | Batch 0500/0500 | Cost: 1.1268
# epoch 28, skip_num 630, loss 0.8331, train acc 74.740%, top_1 test acc 67.620%, top_5 test acc 90.400%
# EPOCH:  29 learning rate:  0.01
# Epoch: 029/050 | Batch 0100/0500 | Cost: 0.5601
# Epoch: 029/050 | Batch 0200/0500 | Cost: 0.8049
# Epoch: 029/050 | Batch 0300/0500 | Cost: 0.7502
# Epoch: 029/050 | Batch 0400/0500 | Cost: 1.1902
# Epoch: 029/050 | Batch 0500/0500 | Cost: 1.8005
# epoch 29, skip_num 644, loss 0.8074, train acc 75.748%, top_1 test acc 67.270%, top_5 test acc 90.120%
# EPOCH:  30 learning rate:  0.01
# Epoch: 030/050 | Batch 0100/0500 | Cost: 0.6330
# Epoch: 030/050 | Batch 0200/0500 | Cost: 0.7372
# Epoch: 030/050 | Batch 0300/0500 | Cost: 1.0983
# Epoch: 030/050 | Batch 0400/0500 | Cost: 1.1207
# Epoch: 030/050 | Batch 0500/0500 | Cost: 0.7498
# epoch 30, skip_num 713, loss 0.7877, train acc 76.038%, top_1 test acc 67.990%, top_5 test acc 91.060%
# EPOCH:  31 learning rate:  0.001
# Epoch: 031/050 | Batch 0100/0500 | Cost: 0.2415
# ****************************************************************************************************
# Iter_num: 15100 Test_acc 92.11 Skip_round: 6773 Comm_round: 144227
# ****************************************************************************************************
# Epoch: 031/050 | Batch 0200/0500 | Cost: 0.5627
# Epoch: 031/050 | Batch 0300/0500 | Cost: 0.2629
# Epoch: 031/050 | Batch 0400/0500 | Cost: 0.8556
# Epoch: 031/050 | Batch 0500/0500 | Cost: 1.2590
# epoch 31, skip_num 137, loss 0.5868, train acc 82.410%, top_1 test acc 71.800%, top_5 test acc 92.590%
# EPOCH:  32 learning rate:  0.001
# Epoch: 032/050 | Batch 0100/0500 | Cost: 0.6509
# Epoch: 032/050 | Batch 0200/0500 | Cost: 1.5716
# Epoch: 032/050 | Batch 0300/0500 | Cost: 1.6315
# Epoch: 032/050 | Batch 0400/0500 | Cost: 0.2682
# Epoch: 032/050 | Batch 0500/0500 | Cost: 0.4645
# epoch 32, skip_num 2356, loss 0.5344, train acc 84.022%, top_1 test acc 72.030%, top_5 test acc 92.420%
# EPOCH:  33 learning rate:  0.001
# Epoch: 033/050 | Batch 0100/0500 | Cost: 0.5861
# Epoch: 033/050 | Batch 0200/0500 | Cost: 0.9067
# Epoch: 033/050 | Batch 0300/0500 | Cost: 0.7542
# Epoch: 033/050 | Batch 0400/0500 | Cost: 0.2625
# Epoch: 033/050 | Batch 0500/0500 | Cost: 0.3143
# epoch 33, skip_num 2370, loss 0.5122, train acc 84.816%, top_1 test acc 71.940%, top_5 test acc 92.810%
# EPOCH:  34 learning rate:  0.001
# Epoch: 034/050 | Batch 0100/0500 | Cost: 1.5124
# Epoch: 034/050 | Batch 0200/0500 | Cost: 0.2550
# Epoch: 034/050 | Batch 0300/0500 | Cost: 1.0527
# Epoch: 034/050 | Batch 0400/0500 | Cost: 0.8003
# Epoch: 034/050 | Batch 0500/0500 | Cost: 0.6356
# epoch 34, skip_num 2319, loss 0.5008, train acc 85.148%, top_1 test acc 72.070%, top_5 test acc 92.560%
# EPOCH:  35 learning rate:  0.001
# Epoch: 035/050 | Batch 0100/0500 | Cost: 0.5972
# Epoch: 035/050 | Batch 0200/0500 | Cost: 0.0746
# Epoch: 035/050 | Batch 0300/0500 | Cost: 0.4209
# Epoch: 035/050 | Batch 0400/0500 | Cost: 0.5556
# Epoch: 035/050 | Batch 0500/0500 | Cost: 0.5722
# epoch 35, skip_num 2335, loss 0.4849, train acc 85.626%, top_1 test acc 72.400%, top_5 test acc 92.520%
# EPOCH:  36 learning rate:  0.001
# Epoch: 036/050 | Batch 0100/0500 | Cost: 0.8573
# Epoch: 036/050 | Batch 0200/0500 | Cost: 0.2797
# Epoch: 036/050 | Batch 0300/0500 | Cost: 0.5268
# Epoch: 036/050 | Batch 0400/0500 | Cost: 0.2830
# Epoch: 036/050 | Batch 0500/0500 | Cost: 0.3305
# epoch 36, skip_num 2324, loss 0.4735, train acc 86.158%, top_1 test acc 72.510%, top_5 test acc 92.630%
# EPOCH:  37 learning rate:  0.001
# Epoch: 037/050 | Batch 0100/0500 | Cost: 1.3656
# Epoch: 037/050 | Batch 0200/0500 | Cost: 0.3924
# Epoch: 037/050 | Batch 0300/0500 | Cost: 0.2683
# Epoch: 037/050 | Batch 0400/0500 | Cost: 0.2710
# Epoch: 037/050 | Batch 0500/0500 | Cost: 0.1664
# epoch 37, skip_num 2237, loss 0.4689, train acc 86.108%, top_1 test acc 72.540%, top_5 test acc 92.650%
# EPOCH:  38 learning rate:  0.001
# Epoch: 038/050 | Batch 0100/0500 | Cost: 0.5387
# Epoch: 038/050 | Batch 0200/0500 | Cost: 0.5736
# Epoch: 038/050 | Batch 0300/0500 | Cost: 0.2742
# Epoch: 038/050 | Batch 0400/0500 | Cost: 0.2819
# Epoch: 038/050 | Batch 0500/0500 | Cost: 0.7046
# epoch 38, skip_num 2281, loss 0.4536, train acc 86.630%, top_1 test acc 72.370%, top_5 test acc 92.660%
# EPOCH:  39 learning rate:  0.001
# Epoch: 039/050 | Batch 0100/0500 | Cost: 0.4018
# Epoch: 039/050 | Batch 0200/0500 | Cost: 0.5428
# Epoch: 039/050 | Batch 0300/0500 | Cost: 0.2398
# Epoch: 039/050 | Batch 0400/0500 | Cost: 0.2585
# Epoch: 039/050 | Batch 0500/0500 | Cost: 0.4315
# epoch 39, skip_num 2221, loss 0.4438, train acc 87.066%, top_1 test acc 72.380%, top_5 test acc 92.440%
# EPOCH:  40 learning rate:  0.001
# Epoch: 040/050 | Batch 0100/0500 | Cost: 0.4706
# Epoch: 040/050 | Batch 0200/0500 | Cost: 0.8396
# Epoch: 040/050 | Batch 0300/0500 | Cost: 0.1214
# Epoch: 040/050 | Batch 0400/0500 | Cost: 0.2739
# Epoch: 040/050 | Batch 0500/0500 | Cost: 0.2664
# epoch 40, skip_num 2258, loss 0.4321, train acc 87.260%, top_1 test acc 72.660%, top_5 test acc 92.730%
# EPOCH:  41 learning rate:  0.001
# Epoch: 041/050 | Batch 0100/0500 | Cost: 0.2716
# Epoch: 041/050 | Batch 0200/0500 | Cost: 0.1307
# Epoch: 041/050 | Batch 0300/0500 | Cost: 0.1733
# Epoch: 041/050 | Batch 0400/0500 | Cost: 0.2059
# Epoch: 041/050 | Batch 0500/0500 | Cost: 0.2165
# epoch 41, skip_num 2161, loss 0.4300, train acc 87.272%, top_1 test acc 72.630%, top_5 test acc 92.540%
# EPOCH:  42 learning rate:  0.001
# Epoch: 042/050 | Batch 0100/0500 | Cost: 0.5111
# Epoch: 042/050 | Batch 0200/0500 | Cost: 0.9667
# Epoch: 042/050 | Batch 0300/0500 | Cost: 0.6072
# Epoch: 042/050 | Batch 0400/0500 | Cost: 0.1608
# Epoch: 042/050 | Batch 0500/0500 | Cost: 0.6304
# epoch 42, skip_num 2231, loss 0.4157, train acc 87.620%, top_1 test acc 72.430%, top_5 test acc 92.720%
# EPOCH:  43 learning rate:  0.001
# Epoch: 043/050 | Batch 0100/0500 | Cost: 0.6047
# Epoch: 043/050 | Batch 0200/0500 | Cost: 0.4329
# Epoch: 043/050 | Batch 0300/0500 | Cost: 0.3655
# Epoch: 043/050 | Batch 0400/0500 | Cost: 0.8130
# Epoch: 043/050 | Batch 0500/0500 | Cost: 0.5505
# epoch 43, skip_num 2171, loss 0.4096, train acc 87.850%, top_1 test acc 72.640%, top_5 test acc 92.620%
# EPOCH:  44 learning rate:  0.001
# Epoch: 044/050 | Batch 0100/0500 | Cost: 0.5951
# Epoch: 044/050 | Batch 0200/0500 | Cost: 0.6275
# Epoch: 044/050 | Batch 0300/0500 | Cost: 0.1661
# Epoch: 044/050 | Batch 0400/0500 | Cost: 0.4624
# Epoch: 044/050 | Batch 0500/0500 | Cost: 0.3587
# epoch 44, skip_num 2155, loss 0.4047, train acc 87.966%, top_1 test acc 72.440%, top_5 test acc 92.430%
# EPOCH:  45 learning rate:  0.001
# Epoch: 045/050 | Batch 0100/0500 | Cost: 0.2342
# Epoch: 045/050 | Batch 0200/0500 | Cost: 0.4854
# Epoch: 045/050 | Batch 0300/0500 | Cost: 0.1944
# Epoch: 045/050 | Batch 0400/0500 | Cost: 0.2058
# Epoch: 045/050 | Batch 0500/0500 | Cost: 0.2791
# epoch 45, skip_num 2166, loss 0.3993, train acc 88.224%, top_1 test acc 72.220%, top_5 test acc 92.440%
# EPOCH:  46 learning rate:  0.001
# Epoch: 046/050 | Batch 0100/0500 | Cost: 0.1520
# Epoch: 046/050 | Batch 0200/0500 | Cost: 0.5898
# Epoch: 046/050 | Batch 0300/0500 | Cost: 0.4740
# Epoch: 046/050 | Batch 0400/0500 | Cost: 0.2267
# Epoch: 046/050 | Batch 0500/0500 | Cost: 0.0570
# epoch 46, skip_num 2120, loss 0.3924, train acc 88.248%, top_1 test acc 72.220%, top_5 test acc 92.530%
# EPOCH:  47 learning rate:  0.001
# Epoch: 047/050 | Batch 0100/0500 | Cost: 0.2132
# Epoch: 047/050 | Batch 0200/0500 | Cost: 0.2819
# Epoch: 047/050 | Batch 0300/0500 | Cost: 0.1247
# Epoch: 047/050 | Batch 0400/0500 | Cost: 0.0720
# Epoch: 047/050 | Batch 0500/0500 | Cost: 0.6444
# epoch 47, skip_num 2054, loss 0.3877, train acc 88.556%, top_1 test acc 72.340%, top_5 test acc 92.580%
# EPOCH:  48 learning rate:  0.001
# Epoch: 048/050 | Batch 0100/0500 | Cost: 0.4932
# Epoch: 048/050 | Batch 0200/0500 | Cost: 0.5739
# Epoch: 048/050 | Batch 0300/0500 | Cost: 0.2185
# Epoch: 048/050 | Batch 0400/0500 | Cost: 0.1031
# Epoch: 048/050 | Batch 0500/0500 | Cost: 0.1737
# epoch 48, skip_num 2091, loss 0.3798, train acc 88.924%, top_1 test acc 72.540%, top_5 test acc 92.470%
# EPOCH:  49 learning rate:  0.001
# Epoch: 049/050 | Batch 0100/0500 | Cost: 0.5680
# Epoch: 049/050 | Batch 0200/0500 | Cost: 0.4386
# Epoch: 049/050 | Batch 0300/0500 | Cost: 0.2930
# Epoch: 049/050 | Batch 0400/0500 | Cost: 0.2951
# Epoch: 049/050 | Batch 0500/0500 | Cost: 0.2077
# epoch 49, skip_num 2090, loss 0.3719, train acc 89.104%, top_1 test acc 72.550%, top_5 test acc 92.600%
# EPOCH:  50 learning rate:  0.001
# Epoch: 050/050 | Batch 0100/0500 | Cost: 0.3862
# Epoch: 050/050 | Batch 0200/0500 | Cost: 0.1637
# Epoch: 050/050 | Batch 0300/0500 | Cost: 0.2082
# Epoch: 050/050 | Batch 0400/0500 | Cost: 0.5331
# Epoch: 050/050 | Batch 0500/0500 | Cost: 0.2133
# epoch 50, skip_num 2116, loss 0.3685, train acc 89.064%, top_1 test acc 72.630%, top_5 test acc 92.480%
# Finished.

# %% [markdown]
# # Sparse

# %%
print("Sparse  lr:"+str(lr)+"--h:"+str(h)+"--epoch:"+str(NUM_EPOCHS)+"--worker:"+str(NUM_WORKERS))
seed_torch(RANDOM_SEED)
model = resnet18()
model.to(DEVICE)
loss = nn.CrossEntropyLoss()  # 损失函数

# prepare data
dataset_name = 'cifar100'
train_loader_workers, test_loader = create_loaders(dataset_name, NUM_WORKERS, BATCH_SIZE)

NUM_PARAS = sum([1 for param in model.parameters()])
print("Number_parameter:", NUM_PARAS)
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Element_parameter:", total_params)

error_worker = [[0 for col in range(NUM_PARAS)] for row in range(NUM_WORKERS)]
Loss_epoch = []
train_acc_epoch = []
test_acc_epoch = []
Loss_iter = []
train_acc_iter = []
test_acc_iter = []
iter_num = 0
flag_acc = False

for epoch in range(NUM_EPOCHS):
    train_l_sum, train_acc_sum, num = 0.0, 0.0, 0
    train_loader_iter = [iter(train_loader_workers[w]) for w in range(NUM_WORKERS)]
    iter_steps = len(train_loader_workers[0])

    # adjust learning_rate
    lr, _ = adjust_lr(epoch)
    print("EPOCH: ", epoch + 1, "learning rate: ", lr)

    for batch_idx in range(iter_steps):
        model.train()
        grad_agg = [0 for col in range(NUM_PARAS)]
        for w_id in range(NUM_WORKERS):
            images, labels = next(train_loader_iter[w_id])
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            y_hat = model(images)
            Loss = loss(y_hat, labels)
            Loss.backward()
            with torch.no_grad():
                p_id = 0
                for p in model.parameters():
                    g = lr * p.grad.data.clone().detach() + error_worker[w_id][p_id]
                    Tk_sparse = top_k_opt(g, h)
                    grad_agg[p_id] += Tk_sparse
                    error_worker[w_id][p_id] = g - Tk_sparse
                    p_id += 1
                    p.grad.zero_()
            train_l_sum += Loss.item()
            train_acc_sum += (y_hat.argmax(dim=1) == labels).sum().item()
            num += labels.shape[0]
        with torch.no_grad():
            p_id = 0
            for p in model.parameters():
                p.data.add_(grad_agg[p_id], alpha=-1)
                p_id += 1
                p.grad.zero_()
        # LOGGING
        if not (batch_idx + 1) % 100:
            print('Epoch: %03d/%03d | Batch %04d/%04d | Cost: %.4f'
                % (epoch + 1, NUM_EPOCHS, batch_idx + 1, len(train_loader_workers[0]), Loss.item()))
        iter_num += 1
        if not iter_num % 100:
            model.eval()
            with torch.no_grad():
                _, test_acc_it = evaluate_accuracy(model, test_loader, DEVICE)
                Loss_iter.append(train_l_sum / (num / BATCH_SIZE))
                train_acc_iter.append(train_acc_sum / num * 100)
                test_acc_iter.append(test_acc_it)
            if test_acc_it > 92.0 and not flag_acc:
                flag_acc = True
                print("*" * 100)
                print("Iter_num:", iter_num, "Test_acc", test_acc_it, "Comm_round:", iter_num * 10)  # 10 workers
                print("*" * 100)
    model.eval()
    with torch.no_grad():
        test_acc_1, test_acc_5 = evaluate_accuracy(model, test_loader, DEVICE)
        Loss_epoch.append(train_l_sum / (num / BATCH_SIZE))
        train_acc_epoch.append(train_acc_sum / num * 100)
        test_acc_epoch.append(test_acc_5)
    print('epoch %d, loss %.4f, train acc %.3f%%, top_1 test acc %.3f%%, top_5 test acc %.3f%%'
        % (epoch + 1, train_l_sum / (num / BATCH_SIZE), train_acc_sum / num * 100, test_acc_1, test_acc_5))

print('Finished.')

list_write = []
list_write.append(Loss_epoch)
list_write.append(train_acc_epoch)
list_write.append(test_acc_epoch)
name = ['Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name, data=list_write).T
test.to_csv("./result/"+"Sparse-res-cifar100.csv", encoding='gbk')


list_write_iter = []
list_write_iter.append(Loss_iter)
list_write_iter.append(train_acc_iter)
list_write_iter.append(test_acc_iter)
name_iter = ['Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name_iter, data=list_write_iter).T
test.to_csv("./result/"+"Sparse-res-cifar100-iter.csv", encoding='gbk')
# Out:
# Sparse  lr:0.001--h:0.01--epoch:50--worker:10
# Files already downloaded and verified
# Files already downloaded and verified
# Number_parameter: 62
# Element_parameter: 11220132
# EPOCH:  1 learning rate:  0.01
# Epoch: 001/050 | Batch 0100/0500 | Cost: 3.4586
# Epoch: 001/050 | Batch 0200/0500 | Cost: 3.3150
# Epoch: 001/050 | Batch 0300/0500 | Cost: 3.1947
# Epoch: 001/050 | Batch 0400/0500 | Cost: 3.5347
# Epoch: 001/050 | Batch 0500/0500 | Cost: 2.8033
# epoch 1, loss 3.7252, train acc 13.086%, top_1 test acc 24.050%, top_5 test acc 53.780%
# EPOCH:  2 learning rate:  0.01
# Epoch: 002/050 | Batch 0100/0500 | Cost: 3.5367
# Epoch: 002/050 | Batch 0200/0500 | Cost: 3.6269
# Epoch: 002/050 | Batch 0300/0500 | Cost: 3.2228
# Epoch: 002/050 | Batch 0400/0500 | Cost: 2.2701
# Epoch: 002/050 | Batch 0500/0500 | Cost: 3.6193
# epoch 2, loss 2.9999, train acc 25.350%, top_1 test acc 34.130%, top_5 test acc 66.870%
# EPOCH:  3 learning rate:  0.01
# Epoch: 003/050 | Batch 0100/0500 | Cost: 2.7223
# Epoch: 003/050 | Batch 0200/0500 | Cost: 3.3210
# Epoch: 003/050 | Batch 0300/0500 | Cost: 2.9552
# Epoch: 003/050 | Batch 0400/0500 | Cost: 1.8224
# Epoch: 003/050 | Batch 0500/0500 | Cost: 2.8754
# epoch 3, loss 2.5764, train acc 33.630%, top_1 test acc 43.310%, top_5 test acc 75.260%
# EPOCH:  4 learning rate:  0.01
# Epoch: 004/050 | Batch 0100/0500 | Cost: 1.6759
# Epoch: 004/050 | Batch 0200/0500 | Cost: 2.0551
# Epoch: 004/050 | Batch 0300/0500 | Cost: 2.1000
# Epoch: 004/050 | Batch 0400/0500 | Cost: 2.3346
# Epoch: 004/050 | Batch 0500/0500 | Cost: 2.4101
# epoch 4, loss 2.2637, train acc 40.398%, top_1 test acc 47.410%, top_5 test acc 78.390%
# EPOCH:  5 learning rate:  0.01
# Epoch: 005/050 | Batch 0100/0500 | Cost: 2.0570
# Epoch: 005/050 | Batch 0200/0500 | Cost: 2.2307
# Epoch: 005/050 | Batch 0300/0500 | Cost: 1.5798
# Epoch: 005/050 | Batch 0400/0500 | Cost: 2.0651
# Epoch: 005/050 | Batch 0500/0500 | Cost: 3.1270
# epoch 5, loss 2.0556, train acc 45.012%, top_1 test acc 51.000%, top_5 test acc 80.800%
# EPOCH:  6 learning rate:  0.01
# Epoch: 006/050 | Batch 0100/0500 | Cost: 2.0912
# Epoch: 006/050 | Batch 0200/0500 | Cost: 2.6050
# Epoch: 006/050 | Batch 0300/0500 | Cost: 2.3066
# Epoch: 006/050 | Batch 0400/0500 | Cost: 1.4175
# Epoch: 006/050 | Batch 0500/0500 | Cost: 3.4855
# epoch 6, loss 1.9015, train acc 48.396%, top_1 test acc 52.900%, top_5 test acc 82.040%
# EPOCH:  7 learning rate:  0.01
# Epoch: 007/050 | Batch 0100/0500 | Cost: 1.5092
# Epoch: 007/050 | Batch 0200/0500 | Cost: 2.2121
# Epoch: 007/050 | Batch 0300/0500 | Cost: 1.2818
# Epoch: 007/050 | Batch 0400/0500 | Cost: 1.4680
# Epoch: 007/050 | Batch 0500/0500 | Cost: 2.6474
# epoch 7, loss 1.7713, train acc 51.448%, top_1 test acc 56.530%, top_5 test acc 84.170%
# EPOCH:  8 learning rate:  0.01
# Epoch: 008/050 | Batch 0100/0500 | Cost: 1.4038
# Epoch: 008/050 | Batch 0200/0500 | Cost: 1.3322
# Epoch: 008/050 | Batch 0300/0500 | Cost: 0.9687
# Epoch: 008/050 | Batch 0400/0500 | Cost: 1.7866
# Epoch: 008/050 | Batch 0500/0500 | Cost: 1.4873
# epoch 8, loss 1.6471, train acc 54.334%, top_1 test acc 57.750%, top_5 test acc 85.390%
# EPOCH:  9 learning rate:  0.01
# Epoch: 009/050 | Batch 0100/0500 | Cost: 2.3163
# Epoch: 009/050 | Batch 0200/0500 | Cost: 1.0131
# Epoch: 009/050 | Batch 0300/0500 | Cost: 1.0666
# Epoch: 009/050 | Batch 0400/0500 | Cost: 1.8349
# Epoch: 009/050 | Batch 0500/0500 | Cost: 1.3963
# epoch 9, loss 1.5693, train acc 56.530%, top_1 test acc 58.430%, top_5 test acc 85.740%
# EPOCH:  10 learning rate:  0.01
# Epoch: 010/050 | Batch 0100/0500 | Cost: 1.1294
# Epoch: 010/050 | Batch 0200/0500 | Cost: 1.6414
# Epoch: 010/050 | Batch 0300/0500 | Cost: 1.5340
# Epoch: 010/050 | Batch 0400/0500 | Cost: 0.8954
# Epoch: 010/050 | Batch 0500/0500 | Cost: 2.9463
# epoch 10, loss 1.4736, train acc 58.622%, top_1 test acc 60.370%, top_5 test acc 86.970%
# EPOCH:  11 learning rate:  0.01
# Epoch: 011/050 | Batch 0100/0500 | Cost: 1.1665
# Epoch: 011/050 | Batch 0200/0500 | Cost: 1.3022
# Epoch: 011/050 | Batch 0300/0500 | Cost: 1.1229
# Epoch: 011/050 | Batch 0400/0500 | Cost: 1.3848
# Epoch: 011/050 | Batch 0500/0500 | Cost: 2.7194
# epoch 11, loss 1.4042, train acc 60.530%, top_1 test acc 61.580%, top_5 test acc 87.870%
# EPOCH:  12 learning rate:  0.01
# Epoch: 012/050 | Batch 0100/0500 | Cost: 1.7952
# Epoch: 012/050 | Batch 0200/0500 | Cost: 0.9096
# Epoch: 012/050 | Batch 0300/0500 | Cost: 0.9033
# Epoch: 012/050 | Batch 0400/0500 | Cost: 1.0586
# Epoch: 012/050 | Batch 0500/0500 | Cost: 0.5253
# epoch 12, loss 1.3403, train acc 61.996%, top_1 test acc 62.270%, top_5 test acc 87.910%
# EPOCH:  13 learning rate:  0.01
# Epoch: 013/050 | Batch 0100/0500 | Cost: 1.3922
# Epoch: 013/050 | Batch 0200/0500 | Cost: 2.0769
# Epoch: 013/050 | Batch 0300/0500 | Cost: 1.5335
# Epoch: 013/050 | Batch 0400/0500 | Cost: 1.7704
# Epoch: 013/050 | Batch 0500/0500 | Cost: 1.0802
# epoch 13, loss 1.2751, train acc 63.580%, top_1 test acc 63.530%, top_5 test acc 88.760%
# EPOCH:  14 learning rate:  0.01
# Epoch: 014/050 | Batch 0100/0500 | Cost: 1.1084
# Epoch: 014/050 | Batch 0200/0500 | Cost: 1.1752
# Epoch: 014/050 | Batch 0300/0500 | Cost: 0.8376
# Epoch: 014/050 | Batch 0400/0500 | Cost: 1.2615
# Epoch: 014/050 | Batch 0500/0500 | Cost: 1.8496
# epoch 14, loss 1.2160, train acc 65.106%, top_1 test acc 64.310%, top_5 test acc 89.210%
# EPOCH:  15 learning rate:  0.01
# Epoch: 015/050 | Batch 0100/0500 | Cost: 0.6744
# Epoch: 015/050 | Batch 0200/0500 | Cost: 0.5733
# Epoch: 015/050 | Batch 0300/0500 | Cost: 1.5243
# Epoch: 015/050 | Batch 0400/0500 | Cost: 1.1627
# Epoch: 015/050 | Batch 0500/0500 | Cost: 1.4530
# epoch 15, loss 1.1669, train acc 66.260%, top_1 test acc 64.780%, top_5 test acc 89.300%
# EPOCH:  16 learning rate:  0.01
# Epoch: 016/050 | Batch 0100/0500 | Cost: 0.7936
# Epoch: 016/050 | Batch 0200/0500 | Cost: 1.7923
# Epoch: 016/050 | Batch 0300/0500 | Cost: 1.0836
# Epoch: 016/050 | Batch 0400/0500 | Cost: 0.6211
# Epoch: 016/050 | Batch 0500/0500 | Cost: 1.5651
# epoch 16, loss 1.1245, train acc 67.178%, top_1 test acc 65.840%, top_5 test acc 89.360%
# EPOCH:  17 learning rate:  0.01
# Epoch: 017/050 | Batch 0100/0500 | Cost: 1.0316
# Epoch: 017/050 | Batch 0200/0500 | Cost: 1.4183
# Epoch: 017/050 | Batch 0300/0500 | Cost: 0.9837
# Epoch: 017/050 | Batch 0400/0500 | Cost: 1.3511
# Epoch: 017/050 | Batch 0500/0500 | Cost: 1.6537
# epoch 17, loss 1.0721, train acc 68.748%, top_1 test acc 65.660%, top_5 test acc 89.770%
# EPOCH:  18 learning rate:  0.01
# Epoch: 018/050 | Batch 0100/0500 | Cost: 0.3933
# Epoch: 018/050 | Batch 0200/0500 | Cost: 0.6524
# Epoch: 018/050 | Batch 0300/0500 | Cost: 0.9799
# Epoch: 018/050 | Batch 0400/0500 | Cost: 1.2219
# Epoch: 018/050 | Batch 0500/0500 | Cost: 0.9688
# epoch 18, loss 1.0354, train acc 69.772%, top_1 test acc 66.290%, top_5 test acc 89.750%
# EPOCH:  19 learning rate:  0.01
# Epoch: 019/050 | Batch 0100/0500 | Cost: 1.0482
# Epoch: 019/050 | Batch 0200/0500 | Cost: 0.7893
# Epoch: 019/050 | Batch 0300/0500 | Cost: 1.5243
# Epoch: 019/050 | Batch 0400/0500 | Cost: 1.2346
# Epoch: 019/050 | Batch 0500/0500 | Cost: 0.8411
# epoch 19, loss 0.9925, train acc 70.748%, top_1 test acc 66.300%, top_5 test acc 90.030%
# EPOCH:  20 learning rate:  0.01
# Epoch: 020/050 | Batch 0100/0500 | Cost: 1.5514
# Epoch: 020/050 | Batch 0200/0500 | Cost: 0.5975
# Epoch: 020/050 | Batch 0300/0500 | Cost: 1.0289
# Epoch: 020/050 | Batch 0400/0500 | Cost: 0.6878
# Epoch: 020/050 | Batch 0500/0500 | Cost: 0.7966
# epoch 20, loss 0.9563, train acc 71.820%, top_1 test acc 67.540%, top_5 test acc 90.370%
# EPOCH:  21 learning rate:  0.01
# Epoch: 021/050 | Batch 0100/0500 | Cost: 1.0383
# Epoch: 021/050 | Batch 0200/0500 | Cost: 0.2058
# Epoch: 021/050 | Batch 0300/0500 | Cost: 1.0838
# Epoch: 021/050 | Batch 0400/0500 | Cost: 0.5034
# Epoch: 021/050 | Batch 0500/0500 | Cost: 1.3007
# epoch 21, loss 0.9171, train acc 72.698%, top_1 test acc 67.450%, top_5 test acc 90.420%
# EPOCH:  22 learning rate:  0.01
# Epoch: 022/050 | Batch 0100/0500 | Cost: 0.6293
# Epoch: 022/050 | Batch 0200/0500 | Cost: 0.1261
# Epoch: 022/050 | Batch 0300/0500 | Cost: 0.5428
# Epoch: 022/050 | Batch 0400/0500 | Cost: 1.7264
# Epoch: 022/050 | Batch 0500/0500 | Cost: 1.9336
# epoch 22, loss 0.8862, train acc 73.530%, top_1 test acc 68.650%, top_5 test acc 90.470%
# EPOCH:  23 learning rate:  0.01
# Epoch: 023/050 | Batch 0100/0500 | Cost: 0.8783
# Epoch: 023/050 | Batch 0200/0500 | Cost: 0.3481
# Epoch: 023/050 | Batch 0300/0500 | Cost: 1.3274
# Epoch: 023/050 | Batch 0400/0500 | Cost: 1.3544
# Epoch: 023/050 | Batch 0500/0500 | Cost: 0.9640
# epoch 23, loss 0.8498, train acc 74.598%, top_1 test acc 68.680%, top_5 test acc 91.270%
# EPOCH:  24 learning rate:  0.01
# Epoch: 024/050 | Batch 0100/0500 | Cost: 0.6941
# Epoch: 024/050 | Batch 0200/0500 | Cost: 0.8280
# Epoch: 024/050 | Batch 0300/0500 | Cost: 0.6498
# Epoch: 024/050 | Batch 0400/0500 | Cost: 1.0572
# Epoch: 024/050 | Batch 0500/0500 | Cost: 0.3766
# epoch 24, loss 0.8149, train acc 75.372%, top_1 test acc 68.090%, top_5 test acc 90.730%
# EPOCH:  25 learning rate:  0.01
# Epoch: 025/050 | Batch 0100/0500 | Cost: 0.9331
# Epoch: 025/050 | Batch 0200/0500 | Cost: 1.2395
# Epoch: 025/050 | Batch 0300/0500 | Cost: 0.9367
# Epoch: 025/050 | Batch 0400/0500 | Cost: 0.7145
# Epoch: 025/050 | Batch 0500/0500 | Cost: 0.8655
# epoch 25, loss 0.7885, train acc 76.174%, top_1 test acc 69.130%, top_5 test acc 91.120%
# EPOCH:  26 learning rate:  0.01
# Epoch: 026/050 | Batch 0100/0500 | Cost: 1.2616
# Epoch: 026/050 | Batch 0200/0500 | Cost: 0.6915
# Epoch: 026/050 | Batch 0300/0500 | Cost: 0.2615
# Epoch: 026/050 | Batch 0400/0500 | Cost: 1.0278
# Epoch: 026/050 | Batch 0500/0500 | Cost: 0.3744
# epoch 26, loss 0.7564, train acc 76.818%, top_1 test acc 68.220%, top_5 test acc 91.080%
# EPOCH:  27 learning rate:  0.01
# Epoch: 027/050 | Batch 0100/0500 | Cost: 1.5887
# Epoch: 027/050 | Batch 0200/0500 | Cost: 0.2789
# Epoch: 027/050 | Batch 0300/0500 | Cost: 1.2078
# Epoch: 027/050 | Batch 0400/0500 | Cost: 0.6540
# Epoch: 027/050 | Batch 0500/0500 | Cost: 1.3610
# epoch 27, loss 0.7296, train acc 77.926%, top_1 test acc 69.100%, top_5 test acc 91.030%
# EPOCH:  28 learning rate:  0.01
# Epoch: 028/050 | Batch 0100/0500 | Cost: 0.8016
# Epoch: 028/050 | Batch 0200/0500 | Cost: 0.9930
# Epoch: 028/050 | Batch 0300/0500 | Cost: 0.5306
# Epoch: 028/050 | Batch 0400/0500 | Cost: 0.6135
# Epoch: 028/050 | Batch 0500/0500 | Cost: 0.6976
# epoch 28, loss 0.6979, train acc 78.638%, top_1 test acc 68.660%, top_5 test acc 91.040%
# EPOCH:  29 learning rate:  0.01
# Epoch: 029/050 | Batch 0100/0500 | Cost: 0.4625
# Epoch: 029/050 | Batch 0200/0500 | Cost: 0.4567
# Epoch: 029/050 | Batch 0300/0500 | Cost: 0.5695
# Epoch: 029/050 | Batch 0400/0500 | Cost: 0.2220
# Epoch: 029/050 | Batch 0500/0500 | Cost: 1.2913
# epoch 29, loss 0.6785, train acc 79.078%, top_1 test acc 69.560%, top_5 test acc 91.220%
# EPOCH:  30 learning rate:  0.01
# Epoch: 030/050 | Batch 0100/0500 | Cost: 0.9118
# Epoch: 030/050 | Batch 0200/0500 | Cost: 0.4669
# Epoch: 030/050 | Batch 0300/0500 | Cost: 0.8209
# Epoch: 030/050 | Batch 0400/0500 | Cost: 0.8813
# Epoch: 030/050 | Batch 0500/0500 | Cost: 0.8546
# epoch 30, loss 0.6480, train acc 80.122%, top_1 test acc 69.720%, top_5 test acc 91.350%
# EPOCH:  31 learning rate:  0.001
# Epoch: 031/050 | Batch 0100/0500 | Cost: 0.2406
# Epoch: 031/050 | Batch 0200/0500 | Cost: 0.5320
# ****************************************************************************************************
# Iter_num: 15200 Test_acc 92.04 Comm_round: 152000
# ****************************************************************************************************
# Epoch: 031/050 | Batch 0300/0500 | Cost: 0.2379
# Epoch: 031/050 | Batch 0400/0500 | Cost: 0.3544
# Epoch: 031/050 | Batch 0500/0500 | Cost: 0.2342
# epoch 31, loss 0.5056, train acc 84.578%, top_1 test acc 72.030%, top_5 test acc 92.530%
# EPOCH:  32 learning rate:  0.001
# Epoch: 032/050 | Batch 0100/0500 | Cost: 0.3819
# Epoch: 032/050 | Batch 0200/0500 | Cost: 0.2895
# Epoch: 032/050 | Batch 0300/0500 | Cost: 1.0708
# Epoch: 032/050 | Batch 0400/0500 | Cost: 0.4560
# Epoch: 032/050 | Batch 0500/0500 | Cost: 0.5356
# epoch 32, loss 0.4262, train acc 87.138%, top_1 test acc 72.510%, top_5 test acc 92.590%
# EPOCH:  33 learning rate:  0.001
# Epoch: 033/050 | Batch 0100/0500 | Cost: 0.8500
# Epoch: 033/050 | Batch 0200/0500 | Cost: 0.4348
# Epoch: 033/050 | Batch 0300/0500 | Cost: 0.4273
# Epoch: 033/050 | Batch 0400/0500 | Cost: 0.3185
# Epoch: 033/050 | Batch 0500/0500 | Cost: 0.2043
# epoch 33, loss 0.4050, train acc 87.790%, top_1 test acc 72.810%, top_5 test acc 92.720%
# EPOCH:  34 learning rate:  0.001
# Epoch: 034/050 | Batch 0100/0500 | Cost: 0.3338
# Epoch: 034/050 | Batch 0200/0500 | Cost: 0.2839
# Epoch: 034/050 | Batch 0300/0500 | Cost: 0.3590
# Epoch: 034/050 | Batch 0400/0500 | Cost: 0.1228
# Epoch: 034/050 | Batch 0500/0500 | Cost: 0.6069
# epoch 34, loss 0.3875, train acc 88.346%, top_1 test acc 72.990%, top_5 test acc 92.540%
# EPOCH:  35 learning rate:  0.001
# Epoch: 035/050 | Batch 0100/0500 | Cost: 0.6413
# Epoch: 035/050 | Batch 0200/0500 | Cost: 0.6291
# Epoch: 035/050 | Batch 0300/0500 | Cost: 0.5721
# Epoch: 035/050 | Batch 0400/0500 | Cost: 0.1220
# Epoch: 035/050 | Batch 0500/0500 | Cost: 0.1126
# epoch 35, loss 0.3778, train acc 88.580%, top_1 test acc 73.070%, top_5 test acc 92.570%
# EPOCH:  36 learning rate:  0.001
# Epoch: 036/050 | Batch 0100/0500 | Cost: 0.2305
# Epoch: 036/050 | Batch 0200/0500 | Cost: 0.7472
# Epoch: 036/050 | Batch 0300/0500 | Cost: 0.3325
# Epoch: 036/050 | Batch 0400/0500 | Cost: 0.5164
# Epoch: 036/050 | Batch 0500/0500 | Cost: 0.7592
# epoch 36, loss 0.3643, train acc 89.086%, top_1 test acc 72.980%, top_5 test acc 92.650%
# EPOCH:  37 learning rate:  0.001
# Epoch: 037/050 | Batch 0100/0500 | Cost: 0.1617
# Epoch: 037/050 | Batch 0200/0500 | Cost: 0.0778
# Epoch: 037/050 | Batch 0300/0500 | Cost: 0.1364
# Epoch: 037/050 | Batch 0400/0500 | Cost: 0.2949
# Epoch: 037/050 | Batch 0500/0500 | Cost: 0.0724
# epoch 37, loss 0.3595, train acc 89.212%, top_1 test acc 73.130%, top_5 test acc 92.880%
# EPOCH:  38 learning rate:  0.001
# Epoch: 038/050 | Batch 0100/0500 | Cost: 0.5063
# Epoch: 038/050 | Batch 0200/0500 | Cost: 0.8772
# Epoch: 038/050 | Batch 0300/0500 | Cost: 0.3382
# Epoch: 038/050 | Batch 0400/0500 | Cost: 0.3519
# Epoch: 038/050 | Batch 0500/0500 | Cost: 0.5116
# epoch 38, loss 0.3464, train acc 89.622%, top_1 test acc 72.890%, top_5 test acc 92.530%
# EPOCH:  39 learning rate:  0.001
# Epoch: 039/050 | Batch 0100/0500 | Cost: 0.0380
# Epoch: 039/050 | Batch 0200/0500 | Cost: 0.6350
# Epoch: 039/050 | Batch 0300/0500 | Cost: 0.4609
# Epoch: 039/050 | Batch 0400/0500 | Cost: 0.8355
# Epoch: 039/050 | Batch 0500/0500 | Cost: 0.5806
# epoch 39, loss 0.3359, train acc 89.972%, top_1 test acc 73.110%, top_5 test acc 92.660%
# EPOCH:  40 learning rate:  0.001
# Epoch: 040/050 | Batch 0100/0500 | Cost: 0.4874
# Epoch: 040/050 | Batch 0200/0500 | Cost: 0.1170
# Epoch: 040/050 | Batch 0300/0500 | Cost: 0.3692
# Epoch: 040/050 | Batch 0400/0500 | Cost: 0.4886
# Epoch: 040/050 | Batch 0500/0500 | Cost: 0.5036
# epoch 40, loss 0.3333, train acc 90.030%, top_1 test acc 73.040%, top_5 test acc 92.780%
# EPOCH:  41 learning rate:  0.001
# Epoch: 041/050 | Batch 0100/0500 | Cost: 0.4638
# Epoch: 041/050 | Batch 0200/0500 | Cost: 0.4760
# Epoch: 041/050 | Batch 0300/0500 | Cost: 0.2860
# Epoch: 041/050 | Batch 0400/0500 | Cost: 0.1642
# Epoch: 041/050 | Batch 0500/0500 | Cost: 0.2993
# epoch 41, loss 0.3264, train acc 90.146%, top_1 test acc 72.830%, top_5 test acc 92.700%
# EPOCH:  42 learning rate:  0.001
# Epoch: 042/050 | Batch 0100/0500 | Cost: 0.1093
# Epoch: 042/050 | Batch 0200/0500 | Cost: 0.2696
# Epoch: 042/050 | Batch 0300/0500 | Cost: 0.4824
# Epoch: 042/050 | Batch 0400/0500 | Cost: 0.5113
# Epoch: 042/050 | Batch 0500/0500 | Cost: 0.1642
# epoch 42, loss 0.3210, train acc 90.360%, top_1 test acc 72.770%, top_5 test acc 92.510%
# EPOCH:  43 learning rate:  0.001
# Epoch: 043/050 | Batch 0100/0500 | Cost: 0.3548
# Epoch: 043/050 | Batch 0200/0500 | Cost: 0.6220
# Epoch: 043/050 | Batch 0300/0500 | Cost: 0.3001
# Epoch: 043/050 | Batch 0400/0500 | Cost: 0.3305
# Epoch: 043/050 | Batch 0500/0500 | Cost: 0.0447
# epoch 43, loss 0.3136, train acc 90.476%, top_1 test acc 73.000%, top_5 test acc 92.670%
# EPOCH:  44 learning rate:  0.001
# Epoch: 044/050 | Batch 0100/0500 | Cost: 0.5111
# Epoch: 044/050 | Batch 0200/0500 | Cost: 0.0573
# Epoch: 044/050 | Batch 0300/0500 | Cost: 0.2641
# Epoch: 044/050 | Batch 0400/0500 | Cost: 0.6124
# Epoch: 044/050 | Batch 0500/0500 | Cost: 0.2908
# epoch 44, loss 0.3096, train acc 90.632%, top_1 test acc 72.960%, top_5 test acc 92.650%
# EPOCH:  45 learning rate:  0.001
# Epoch: 045/050 | Batch 0100/0500 | Cost: 0.2059
# Epoch: 045/050 | Batch 0200/0500 | Cost: 0.5350
# Epoch: 045/050 | Batch 0300/0500 | Cost: 0.0704
# Epoch: 045/050 | Batch 0400/0500 | Cost: 0.3844
# Epoch: 045/050 | Batch 0500/0500 | Cost: 0.3390
# epoch 45, loss 0.3039, train acc 90.862%, top_1 test acc 73.020%, top_5 test acc 92.460%
# EPOCH:  46 learning rate:  0.001
# Epoch: 046/050 | Batch 0100/0500 | Cost: 0.3879
# Epoch: 046/050 | Batch 0200/0500 | Cost: 0.5390
# Epoch: 046/050 | Batch 0300/0500 | Cost: 0.4921
# Epoch: 046/050 | Batch 0400/0500 | Cost: 0.2558
# Epoch: 046/050 | Batch 0500/0500 | Cost: 0.3817
# epoch 46, loss 0.2950, train acc 91.214%, top_1 test acc 73.110%, top_5 test acc 92.560%
# EPOCH:  47 learning rate:  0.001
# Epoch: 047/050 | Batch 0100/0500 | Cost: 0.2340
# Epoch: 047/050 | Batch 0200/0500 | Cost: 0.5450
# Epoch: 047/050 | Batch 0300/0500 | Cost: 0.1636
# Epoch: 047/050 | Batch 0400/0500 | Cost: 0.7602
# Epoch: 047/050 | Batch 0500/0500 | Cost: 0.2655
# epoch 47, loss 0.2897, train acc 91.234%, top_1 test acc 73.020%, top_5 test acc 92.650%
# EPOCH:  48 learning rate:  0.001
# Epoch: 048/050 | Batch 0100/0500 | Cost: 0.4607
# Epoch: 048/050 | Batch 0200/0500 | Cost: 1.0444
# Epoch: 048/050 | Batch 0300/0500 | Cost: 0.7644
# Epoch: 048/050 | Batch 0400/0500 | Cost: 0.5833
# Epoch: 048/050 | Batch 0500/0500 | Cost: 0.1985
# epoch 48, loss 0.2838, train acc 91.532%, top_1 test acc 73.260%, top_5 test acc 92.510%
# EPOCH:  49 learning rate:  0.001
# Epoch: 049/050 | Batch 0100/0500 | Cost: 0.2437
# Epoch: 049/050 | Batch 0200/0500 | Cost: 0.0521
# Epoch: 049/050 | Batch 0300/0500 | Cost: 0.3159
# Epoch: 049/050 | Batch 0400/0500 | Cost: 0.0571
# Epoch: 049/050 | Batch 0500/0500 | Cost: 0.5573
# epoch 49, loss 0.2796, train acc 91.574%, top_1 test acc 72.950%, top_5 test acc 92.640%
# EPOCH:  50 learning rate:  0.001
# Epoch: 050/050 | Batch 0100/0500 | Cost: 0.4851
# Epoch: 050/050 | Batch 0200/0500 | Cost: 0.1707
# Epoch: 050/050 | Batch 0300/0500 | Cost: 0.4652
# Epoch: 050/050 | Batch 0400/0500 | Cost: 0.3032
# Epoch: 050/050 | Batch 0500/0500 | Cost: 0.1775
# epoch 50, loss 0.2811, train acc 91.576%, top_1 test acc 73.110%, top_5 test acc 92.550%
# Finished.

# %% [markdown]
# # SGD

# %%
print("Dis-SGD  lr:"+str(lr)+"--epoch:"+str(NUM_EPOCHS)+"--worker:"+str(NUM_WORKERS))
seed_torch(RANDOM_SEED)
model = resnet18()
model.to(DEVICE)
loss = nn.CrossEntropyLoss()  # 损失函数

# prepare data
dataset_name = 'cifar100'
train_loader_workers, test_loader = create_loaders(dataset_name, NUM_WORKERS, BATCH_SIZE)

NUM_PARAS = sum([1 for param in model.parameters()])
print("Number_parameter:", NUM_PARAS)
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Element_parameter:", total_params)

Loss_epoch = []
train_acc_epoch = []
test_acc_epoch = []
Loss_iter = []
train_acc_iter = []
test_acc_iter = []
iter_num = 0
flag_acc = False

for epoch in range(NUM_EPOCHS):
    train_l_sum, train_acc_sum, num = 0.0, 0.0, 0
    train_loader_iter = [iter(train_loader_workers[w]) for w in range(NUM_WORKERS)]
    iter_steps = len(train_loader_workers[0])

    # adjust learning_rate
    lr, _= adjust_lr(epoch)
    print("EPOCH: ", epoch + 1, "learning rate: ", lr)

    for batch_idx in range(iter_steps):
        model.train()
        grad_agg = [0 for col in range(NUM_PARAS)]
        for w_id in range(NUM_WORKERS):
            images, labels = next(train_loader_iter[w_id])
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            y_hat = model(images)
            Loss = loss(y_hat, labels)
            Loss.backward()
            with torch.no_grad():
                p_id = 0
                for p in model.parameters():
                    grad_agg[p_id] += lr * p.grad.data.clone().detach()
                    p_id += 1
                    p.grad.zero_()
            train_l_sum += Loss.item()
            train_acc_sum += (y_hat.argmax(dim=1) == labels).sum().item()
            num += labels.shape[0]
        with torch.no_grad():
            p_id = 0
            for p in model.parameters():
                p.data.add_(grad_agg[p_id], alpha=-1)
                p_id += 1
                p.grad.zero_()
        # LOGGING
        if not (batch_idx + 1) % 100:
            print('Epoch: %03d/%03d | Batch %04d/%04d | Cost: %.4f'
                % (epoch + 1, NUM_EPOCHS, batch_idx + 1, len(train_loader_workers[0]), Loss.item()))
        iter_num += 1
        if not iter_num % 100:
            model.eval()
            with torch.no_grad():
                _, test_acc_it = evaluate_accuracy(model, test_loader, DEVICE)
                Loss_iter.append(train_l_sum / (num / BATCH_SIZE))
                train_acc_iter.append(train_acc_sum / num * 100)
                test_acc_iter.append(test_acc_it)
            if test_acc_it > 92.0 and not flag_acc:
                flag_acc = True
                print("*" * 100)
                print("Iter_num:", iter_num, "Test_acc", test_acc_it, "Comm_round:", iter_num * 10)  # 10 workers
                print("*" * 100)
    model.eval()
    with torch.no_grad():
        test_acc_1, test_acc_5 = evaluate_accuracy(model, test_loader, DEVICE)
        Loss_epoch.append(train_l_sum / (num / BATCH_SIZE))
        train_acc_epoch.append(train_acc_sum / num * 100)
        test_acc_epoch.append(test_acc_5)
    print('epoch %d, loss %.4f, train acc %.3f%%, top_1 test acc %.3f%%, top_5 test acc %.3f%%'
        % (epoch + 1, train_l_sum / (num / BATCH_SIZE), train_acc_sum / num * 100, test_acc_1, test_acc_5))

print('Finished.')

list_write = []
list_write.append(Loss_epoch)
list_write.append(train_acc_epoch)
list_write.append(test_acc_epoch)
name = ['Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name, data=list_write).T
test.to_csv("./result/"+"SGD-res-cifar100.csv", encoding='gbk')

list_write_iter = []
list_write_iter.append(Loss_iter)
list_write_iter.append(train_acc_iter)
list_write_iter.append(test_acc_iter)
name_iter = ['Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name_iter, data=list_write_iter).T
test.to_csv("./result/"+"SGD-res-cifar100-iter.csv", encoding='gbk')
# Out:
# Dis-SGD  lr:0.001--epoch:50--worker:10
# Files already downloaded and verified
# Files already downloaded and verified
# Number_parameter: 62
# Element_parameter: 11220132
# EPOCH:  1 learning rate:  0.01
# Epoch: 001/050 | Batch 0100/0500 | Cost: 3.7957
# Epoch: 001/050 | Batch 0200/0500 | Cost: 3.7933
# Epoch: 001/050 | Batch 0300/0500 | Cost: 3.3922
# Epoch: 001/050 | Batch 0400/0500 | Cost: 3.9361
# Epoch: 001/050 | Batch 0500/0500 | Cost: 3.0497
# epoch 1, loss 3.8300, train acc 11.246%, top_1 test acc 19.330%, top_5 test acc 47.550%
# EPOCH:  2 learning rate:  0.01
# Epoch: 002/050 | Batch 0100/0500 | Cost: 3.7818
# Epoch: 002/050 | Batch 0200/0500 | Cost: 2.9568
# Epoch: 002/050 | Batch 0300/0500 | Cost: 3.3002
# Epoch: 002/050 | Batch 0400/0500 | Cost: 2.8261
# Epoch: 002/050 | Batch 0500/0500 | Cost: 3.6864
# epoch 2, loss 3.1265, train acc 22.478%, top_1 test acc 30.980%, top_5 test acc 62.290%
# EPOCH:  3 learning rate:  0.01
# Epoch: 003/050 | Batch 0100/0500 | Cost: 2.6123
# Epoch: 003/050 | Batch 0200/0500 | Cost: 3.9057
# Epoch: 003/050 | Batch 0300/0500 | Cost: 2.8710
# Epoch: 003/050 | Batch 0400/0500 | Cost: 2.3579
# Epoch: 003/050 | Batch 0500/0500 | Cost: 2.6867
# epoch 3, loss 2.6954, train acc 30.976%, top_1 test acc 37.620%, top_5 test acc 72.000%
# EPOCH:  4 learning rate:  0.01
# Epoch: 004/050 | Batch 0100/0500 | Cost: 1.8332
# Epoch: 004/050 | Batch 0200/0500 | Cost: 2.3700
# Epoch: 004/050 | Batch 0300/0500 | Cost: 2.1828
# Epoch: 004/050 | Batch 0400/0500 | Cost: 2.4082
# Epoch: 004/050 | Batch 0500/0500 | Cost: 2.3415
# epoch 4, loss 2.3751, train acc 37.690%, top_1 test acc 44.420%, top_5 test acc 75.910%
# EPOCH:  5 learning rate:  0.01
# Epoch: 005/050 | Batch 0100/0500 | Cost: 2.5652
# Epoch: 005/050 | Batch 0200/0500 | Cost: 2.0686
# Epoch: 005/050 | Batch 0300/0500 | Cost: 1.6608
# Epoch: 005/050 | Batch 0400/0500 | Cost: 1.8595
# Epoch: 005/050 | Batch 0500/0500 | Cost: 2.8205
# epoch 5, loss 2.1517, train acc 42.688%, top_1 test acc 48.700%, top_5 test acc 78.690%
# EPOCH:  6 learning rate:  0.01
# Epoch: 006/050 | Batch 0100/0500 | Cost: 1.8714
# Epoch: 006/050 | Batch 0200/0500 | Cost: 2.4200
# Epoch: 006/050 | Batch 0300/0500 | Cost: 2.3681
# Epoch: 006/050 | Batch 0400/0500 | Cost: 1.5012
# Epoch: 006/050 | Batch 0500/0500 | Cost: 2.7491
# epoch 6, loss 1.9936, train acc 46.312%, top_1 test acc 49.500%, top_5 test acc 80.060%
# EPOCH:  7 learning rate:  0.01
# Epoch: 007/050 | Batch 0100/0500 | Cost: 1.4195
# Epoch: 007/050 | Batch 0200/0500 | Cost: 2.2392
# Epoch: 007/050 | Batch 0300/0500 | Cost: 1.4203
# Epoch: 007/050 | Batch 0400/0500 | Cost: 1.5065
# Epoch: 007/050 | Batch 0500/0500 | Cost: 2.0296
# epoch 7, loss 1.8610, train acc 49.178%, top_1 test acc 53.110%, top_5 test acc 82.710%
# EPOCH:  8 learning rate:  0.01
# Epoch: 008/050 | Batch 0100/0500 | Cost: 1.6605
# Epoch: 008/050 | Batch 0200/0500 | Cost: 1.4550
# Epoch: 008/050 | Batch 0300/0500 | Cost: 1.1016
# Epoch: 008/050 | Batch 0400/0500 | Cost: 2.2335
# Epoch: 008/050 | Batch 0500/0500 | Cost: 1.9565
# epoch 8, loss 1.7365, train acc 52.070%, top_1 test acc 53.410%, top_5 test acc 82.620%
# EPOCH:  9 learning rate:  0.01
# Epoch: 009/050 | Batch 0100/0500 | Cost: 1.9499
# Epoch: 009/050 | Batch 0200/0500 | Cost: 1.1299
# Epoch: 009/050 | Batch 0300/0500 | Cost: 1.5052
# Epoch: 009/050 | Batch 0400/0500 | Cost: 2.1892
# Epoch: 009/050 | Batch 0500/0500 | Cost: 1.5877
# epoch 9, loss 1.6546, train acc 54.220%, top_1 test acc 54.970%, top_5 test acc 83.850%
# EPOCH:  10 learning rate:  0.01
# Epoch: 010/050 | Batch 0100/0500 | Cost: 0.8828
# Epoch: 010/050 | Batch 0200/0500 | Cost: 2.7812
# Epoch: 010/050 | Batch 0300/0500 | Cost: 1.6840
# Epoch: 010/050 | Batch 0400/0500 | Cost: 0.9196
# Epoch: 010/050 | Batch 0500/0500 | Cost: 2.3460
# epoch 10, loss 1.5589, train acc 56.462%, top_1 test acc 57.120%, top_5 test acc 84.780%
# EPOCH:  11 learning rate:  0.01
# Epoch: 011/050 | Batch 0100/0500 | Cost: 1.1654
# Epoch: 011/050 | Batch 0200/0500 | Cost: 1.4836
# Epoch: 011/050 | Batch 0300/0500 | Cost: 1.3496
# Epoch: 011/050 | Batch 0400/0500 | Cost: 1.2105
# Epoch: 011/050 | Batch 0500/0500 | Cost: 2.5135
# epoch 11, loss 1.4852, train acc 58.350%, top_1 test acc 59.120%, top_5 test acc 86.480%
# EPOCH:  12 learning rate:  0.01
# Epoch: 012/050 | Batch 0100/0500 | Cost: 1.8058
# Epoch: 012/050 | Batch 0200/0500 | Cost: 1.3012
# Epoch: 012/050 | Batch 0300/0500 | Cost: 0.8124
# Epoch: 012/050 | Batch 0400/0500 | Cost: 1.1108
# Epoch: 012/050 | Batch 0500/0500 | Cost: 0.6627
# epoch 12, loss 1.4187, train acc 60.094%, top_1 test acc 58.720%, top_5 test acc 86.150%
# EPOCH:  13 learning rate:  0.01
# Epoch: 013/050 | Batch 0100/0500 | Cost: 1.4101
# Epoch: 013/050 | Batch 0200/0500 | Cost: 1.5374
# Epoch: 013/050 | Batch 0300/0500 | Cost: 1.7045
# Epoch: 013/050 | Batch 0400/0500 | Cost: 1.7578
# Epoch: 013/050 | Batch 0500/0500 | Cost: 1.1862
# epoch 13, loss 1.3585, train acc 61.732%, top_1 test acc 60.240%, top_5 test acc 87.030%
# EPOCH:  14 learning rate:  0.01
# Epoch: 014/050 | Batch 0100/0500 | Cost: 1.2888
# Epoch: 014/050 | Batch 0200/0500 | Cost: 0.8770
# Epoch: 014/050 | Batch 0300/0500 | Cost: 0.8641
# Epoch: 014/050 | Batch 0400/0500 | Cost: 1.4144
# Epoch: 014/050 | Batch 0500/0500 | Cost: 1.6742
# epoch 14, loss 1.2949, train acc 62.870%, top_1 test acc 61.300%, top_5 test acc 87.270%
# EPOCH:  15 learning rate:  0.01
# Epoch: 015/050 | Batch 0100/0500 | Cost: 0.9535
# Epoch: 015/050 | Batch 0200/0500 | Cost: 0.7624
# Epoch: 015/050 | Batch 0300/0500 | Cost: 1.0213
# Epoch: 015/050 | Batch 0400/0500 | Cost: 1.1944
# Epoch: 015/050 | Batch 0500/0500 | Cost: 1.5618
# epoch 15, loss 1.2490, train acc 64.154%, top_1 test acc 61.780%, top_5 test acc 87.720%
# EPOCH:  16 learning rate:  0.01
# Epoch: 016/050 | Batch 0100/0500 | Cost: 0.7020
# Epoch: 016/050 | Batch 0200/0500 | Cost: 1.8049
# Epoch: 016/050 | Batch 0300/0500 | Cost: 1.0601
# Epoch: 016/050 | Batch 0400/0500 | Cost: 0.8692
# Epoch: 016/050 | Batch 0500/0500 | Cost: 1.3635
# epoch 16, loss 1.2025, train acc 65.556%, top_1 test acc 63.940%, top_5 test acc 88.740%
# EPOCH:  17 learning rate:  0.01
# Epoch: 017/050 | Batch 0100/0500 | Cost: 1.1765
# Epoch: 017/050 | Batch 0200/0500 | Cost: 1.5819
# Epoch: 017/050 | Batch 0300/0500 | Cost: 1.4177
# Epoch: 017/050 | Batch 0400/0500 | Cost: 1.7637
# Epoch: 017/050 | Batch 0500/0500 | Cost: 1.4009
# epoch 17, loss 1.1487, train acc 66.614%, top_1 test acc 62.410%, top_5 test acc 88.270%
# EPOCH:  18 learning rate:  0.01
# Epoch: 018/050 | Batch 0100/0500 | Cost: 0.4272
# Epoch: 018/050 | Batch 0200/0500 | Cost: 0.8739
# Epoch: 018/050 | Batch 0300/0500 | Cost: 1.2300
# Epoch: 018/050 | Batch 0400/0500 | Cost: 1.3630
# Epoch: 018/050 | Batch 0500/0500 | Cost: 0.8754
# epoch 18, loss 1.1043, train acc 67.766%, top_1 test acc 64.220%, top_5 test acc 89.320%
# EPOCH:  19 learning rate:  0.01
# Epoch: 019/050 | Batch 0100/0500 | Cost: 0.5505
# Epoch: 019/050 | Batch 0200/0500 | Cost: 0.9214
# Epoch: 019/050 | Batch 0300/0500 | Cost: 1.6181
# Epoch: 019/050 | Batch 0400/0500 | Cost: 1.5047
# Epoch: 019/050 | Batch 0500/0500 | Cost: 0.7844
# epoch 19, loss 1.0683, train acc 68.636%, top_1 test acc 66.180%, top_5 test acc 89.490%
# EPOCH:  20 learning rate:  0.01
# Epoch: 020/050 | Batch 0100/0500 | Cost: 1.4352
# Epoch: 020/050 | Batch 0200/0500 | Cost: 0.6798
# Epoch: 020/050 | Batch 0300/0500 | Cost: 1.1760
# Epoch: 020/050 | Batch 0400/0500 | Cost: 0.7302
# Epoch: 020/050 | Batch 0500/0500 | Cost: 0.9996
# epoch 20, loss 1.0219, train acc 70.026%, top_1 test acc 66.110%, top_5 test acc 90.010%
# EPOCH:  21 learning rate:  0.01
# Epoch: 021/050 | Batch 0100/0500 | Cost: 1.1979
# Epoch: 021/050 | Batch 0200/0500 | Cost: 0.4879
# Epoch: 021/050 | Batch 0300/0500 | Cost: 1.1882
# Epoch: 021/050 | Batch 0400/0500 | Cost: 1.0127
# Epoch: 021/050 | Batch 0500/0500 | Cost: 1.2392
# epoch 21, loss 0.9887, train acc 70.908%, top_1 test acc 65.530%, top_5 test acc 89.370%
# EPOCH:  22 learning rate:  0.01
# Epoch: 022/050 | Batch 0100/0500 | Cost: 0.9064
# Epoch: 022/050 | Batch 0200/0500 | Cost: 0.2123
# Epoch: 022/050 | Batch 0300/0500 | Cost: 0.6314
# Epoch: 022/050 | Batch 0400/0500 | Cost: 1.3472
# Epoch: 022/050 | Batch 0500/0500 | Cost: 1.3420
# epoch 22, loss 0.9504, train acc 71.790%, top_1 test acc 66.440%, top_5 test acc 90.350%
# EPOCH:  23 learning rate:  0.01
# Epoch: 023/050 | Batch 0100/0500 | Cost: 0.9837
# Epoch: 023/050 | Batch 0200/0500 | Cost: 0.5061
# Epoch: 023/050 | Batch 0300/0500 | Cost: 1.2098
# Epoch: 023/050 | Batch 0400/0500 | Cost: 1.0400
# Epoch: 023/050 | Batch 0500/0500 | Cost: 1.2684
# epoch 23, loss 0.9179, train acc 72.414%, top_1 test acc 66.740%, top_5 test acc 90.000%
# EPOCH:  24 learning rate:  0.01
# Epoch: 024/050 | Batch 0100/0500 | Cost: 0.8033
# Epoch: 024/050 | Batch 0200/0500 | Cost: 0.6313
# Epoch: 024/050 | Batch 0300/0500 | Cost: 0.3601
# Epoch: 024/050 | Batch 0400/0500 | Cost: 1.0622
# Epoch: 024/050 | Batch 0500/0500 | Cost: 0.5120
# epoch 24, loss 0.8809, train acc 73.610%, top_1 test acc 66.280%, top_5 test acc 90.190%
# EPOCH:  25 learning rate:  0.01
# Epoch: 025/050 | Batch 0100/0500 | Cost: 0.8146
# Epoch: 025/050 | Batch 0200/0500 | Cost: 0.8742
# Epoch: 025/050 | Batch 0300/0500 | Cost: 1.1524
# Epoch: 025/050 | Batch 0400/0500 | Cost: 0.6717
# Epoch: 025/050 | Batch 0500/0500 | Cost: 1.2260
# epoch 25, loss 0.8453, train acc 74.510%, top_1 test acc 68.440%, top_5 test acc 90.770%
# EPOCH:  26 learning rate:  0.01
# Epoch: 026/050 | Batch 0100/0500 | Cost: 2.1441
# Epoch: 026/050 | Batch 0200/0500 | Cost: 0.9057
# Epoch: 026/050 | Batch 0300/0500 | Cost: 0.6054
# Epoch: 026/050 | Batch 0400/0500 | Cost: 1.4630
# Epoch: 026/050 | Batch 0500/0500 | Cost: 0.5622
# epoch 26, loss 0.8187, train acc 75.260%, top_1 test acc 67.720%, top_5 test acc 90.280%
# EPOCH:  27 learning rate:  0.01
# Epoch: 027/050 | Batch 0100/0500 | Cost: 1.6201
# Epoch: 027/050 | Batch 0200/0500 | Cost: 0.5869
# Epoch: 027/050 | Batch 0300/0500 | Cost: 1.6841
# Epoch: 027/050 | Batch 0400/0500 | Cost: 0.7857
# Epoch: 027/050 | Batch 0500/0500 | Cost: 1.7414
# epoch 27, loss 0.7852, train acc 76.276%, top_1 test acc 68.670%, top_5 test acc 90.710%
# EPOCH:  28 learning rate:  0.01
# Epoch: 028/050 | Batch 0100/0500 | Cost: 0.7045
# Epoch: 028/050 | Batch 0200/0500 | Cost: 0.9625
# Epoch: 028/050 | Batch 0300/0500 | Cost: 1.0043
# Epoch: 028/050 | Batch 0400/0500 | Cost: 0.2380
# Epoch: 028/050 | Batch 0500/0500 | Cost: 0.9265
# epoch 28, loss 0.7658, train acc 76.648%, top_1 test acc 68.010%, top_5 test acc 91.010%
# EPOCH:  29 learning rate:  0.01
# Epoch: 029/050 | Batch 0100/0500 | Cost: 0.9740
# Epoch: 029/050 | Batch 0200/0500 | Cost: 0.7986
# Epoch: 029/050 | Batch 0300/0500 | Cost: 0.4905
# Epoch: 029/050 | Batch 0400/0500 | Cost: 0.2697
# Epoch: 029/050 | Batch 0500/0500 | Cost: 1.0174
# epoch 29, loss 0.7427, train acc 77.270%, top_1 test acc 69.150%, top_5 test acc 90.780%
# EPOCH:  30 learning rate:  0.01
# Epoch: 030/050 | Batch 0100/0500 | Cost: 1.4207
# Epoch: 030/050 | Batch 0200/0500 | Cost: 0.7269
# Epoch: 030/050 | Batch 0300/0500 | Cost: 0.6413
# Epoch: 030/050 | Batch 0400/0500 | Cost: 1.3647
# Epoch: 030/050 | Batch 0500/0500 | Cost: 0.7694
# epoch 30, loss 0.7078, train acc 78.448%, top_1 test acc 69.920%, top_5 test acc 91.180%
# EPOCH:  31 learning rate:  0.001
# Epoch: 031/050 | Batch 0100/0500 | Cost: 0.3183
# ****************************************************************************************************
# Iter_num: 15100 Test_acc 92.05 Comm_round: 151000
# ****************************************************************************************************
# Epoch: 031/050 | Batch 0200/0500 | Cost: 0.4802
# Epoch: 031/050 | Batch 0300/0500 | Cost: 0.3795
# Epoch: 031/050 | Batch 0400/0500 | Cost: 0.6775
# Epoch: 031/050 | Batch 0500/0500 | Cost: 0.2131
# epoch 31, loss 0.5248, train acc 84.248%, top_1 test acc 72.750%, top_5 test acc 92.630%
# EPOCH:  32 learning rate:  0.001
# Epoch: 032/050 | Batch 0100/0500 | Cost: 0.4915
# Epoch: 032/050 | Batch 0200/0500 | Cost: 0.4512
# Epoch: 032/050 | Batch 0300/0500 | Cost: 1.4688
# Epoch: 032/050 | Batch 0400/0500 | Cost: 0.3481
# Epoch: 032/050 | Batch 0500/0500 | Cost: 0.6243
# epoch 32, loss 0.4711, train acc 86.028%, top_1 test acc 72.910%, top_5 test acc 92.630%
# EPOCH:  33 learning rate:  0.001
# Epoch: 033/050 | Batch 0100/0500 | Cost: 0.8402
# Epoch: 033/050 | Batch 0200/0500 | Cost: 1.0917
# Epoch: 033/050 | Batch 0300/0500 | Cost: 0.3212
# Epoch: 033/050 | Batch 0400/0500 | Cost: 0.3521
# Epoch: 033/050 | Batch 0500/0500 | Cost: 0.0872
# epoch 33, loss 0.4478, train acc 86.408%, top_1 test acc 73.230%, top_5 test acc 92.650%
# EPOCH:  34 learning rate:  0.001
# Epoch: 034/050 | Batch 0100/0500 | Cost: 0.1142
# Epoch: 034/050 | Batch 0200/0500 | Cost: 0.3708
# Epoch: 034/050 | Batch 0300/0500 | Cost: 0.2578
# Epoch: 034/050 | Batch 0400/0500 | Cost: 0.2318
# Epoch: 034/050 | Batch 0500/0500 | Cost: 0.5292
# epoch 34, loss 0.4322, train acc 87.190%, top_1 test acc 73.200%, top_5 test acc 92.610%
# EPOCH:  35 learning rate:  0.001
# Epoch: 035/050 | Batch 0100/0500 | Cost: 0.5694
# Epoch: 035/050 | Batch 0200/0500 | Cost: 0.6048
# Epoch: 035/050 | Batch 0300/0500 | Cost: 0.4814
# Epoch: 035/050 | Batch 0400/0500 | Cost: 0.3542
# Epoch: 035/050 | Batch 0500/0500 | Cost: 0.2225
# epoch 35, loss 0.4231, train acc 87.222%, top_1 test acc 73.050%, top_5 test acc 92.710%
# EPOCH:  36 learning rate:  0.001
# Epoch: 036/050 | Batch 0100/0500 | Cost: 0.5003
# Epoch: 036/050 | Batch 0200/0500 | Cost: 0.8541
# Epoch: 036/050 | Batch 0300/0500 | Cost: 0.3834
# Epoch: 036/050 | Batch 0400/0500 | Cost: 0.5052
# Epoch: 036/050 | Batch 0500/0500 | Cost: 1.7627
# epoch 36, loss 0.4087, train acc 87.760%, top_1 test acc 73.280%, top_5 test acc 92.780%
# EPOCH:  37 learning rate:  0.001
# Epoch: 037/050 | Batch 0100/0500 | Cost: 0.2563
# Epoch: 037/050 | Batch 0200/0500 | Cost: 0.2193
# Epoch: 037/050 | Batch 0300/0500 | Cost: 0.2438
# Epoch: 037/050 | Batch 0400/0500 | Cost: 0.3618
# Epoch: 037/050 | Batch 0500/0500 | Cost: 0.2103
# epoch 37, loss 0.4029, train acc 87.894%, top_1 test acc 73.680%, top_5 test acc 92.670%
# EPOCH:  38 learning rate:  0.001
# Epoch: 038/050 | Batch 0100/0500 | Cost: 0.4706
# Epoch: 038/050 | Batch 0200/0500 | Cost: 0.9225
# Epoch: 038/050 | Batch 0300/0500 | Cost: 0.3979
# Epoch: 038/050 | Batch 0400/0500 | Cost: 0.4078
# Epoch: 038/050 | Batch 0500/0500 | Cost: 0.4083
# epoch 38, loss 0.3939, train acc 88.212%, top_1 test acc 73.570%, top_5 test acc 92.580%
# EPOCH:  39 learning rate:  0.001
# Epoch: 039/050 | Batch 0100/0500 | Cost: 0.1032
# Epoch: 039/050 | Batch 0200/0500 | Cost: 0.7254
# Epoch: 039/050 | Batch 0300/0500 | Cost: 0.1796
# Epoch: 039/050 | Batch 0400/0500 | Cost: 0.7353
# Epoch: 039/050 | Batch 0500/0500 | Cost: 0.4119
# epoch 39, loss 0.3813, train acc 88.604%, top_1 test acc 73.080%, top_5 test acc 92.470%
# EPOCH:  40 learning rate:  0.001
# Epoch: 040/050 | Batch 0100/0500 | Cost: 0.6229
# Epoch: 040/050 | Batch 0200/0500 | Cost: 0.0493
# Epoch: 040/050 | Batch 0300/0500 | Cost: 0.7050
# Epoch: 040/050 | Batch 0400/0500 | Cost: 0.2456
# Epoch: 040/050 | Batch 0500/0500 | Cost: 0.6457
# epoch 40, loss 0.3802, train acc 88.778%, top_1 test acc 73.160%, top_5 test acc 92.680%
# EPOCH:  41 learning rate:  0.001
# Epoch: 041/050 | Batch 0100/0500 | Cost: 0.8980
# Epoch: 041/050 | Batch 0200/0500 | Cost: 0.3325
# Epoch: 041/050 | Batch 0300/0500 | Cost: 0.6817
# Epoch: 041/050 | Batch 0400/0500 | Cost: 0.3485
# Epoch: 041/050 | Batch 0500/0500 | Cost: 0.5389
# epoch 41, loss 0.3695, train acc 88.664%, top_1 test acc 73.290%, top_5 test acc 92.690%
# EPOCH:  42 learning rate:  0.001
# Epoch: 042/050 | Batch 0100/0500 | Cost: 0.2008
# Epoch: 042/050 | Batch 0200/0500 | Cost: 0.5385
# Epoch: 042/050 | Batch 0300/0500 | Cost: 0.4309
# Epoch: 042/050 | Batch 0400/0500 | Cost: 0.8857
# Epoch: 042/050 | Batch 0500/0500 | Cost: 0.1024
# epoch 42, loss 0.3644, train acc 89.066%, top_1 test acc 73.240%, top_5 test acc 92.720%
# EPOCH:  43 learning rate:  0.001
# Epoch: 043/050 | Batch 0100/0500 | Cost: 0.2778
# Epoch: 043/050 | Batch 0200/0500 | Cost: 0.5630
# Epoch: 043/050 | Batch 0300/0500 | Cost: 0.3556
# Epoch: 043/050 | Batch 0400/0500 | Cost: 0.1946
# Epoch: 043/050 | Batch 0500/0500 | Cost: 0.2420
# epoch 43, loss 0.3557, train acc 89.346%, top_1 test acc 73.410%, top_5 test acc 92.580%
# EPOCH:  44 learning rate:  0.001
# Epoch: 044/050 | Batch 0100/0500 | Cost: 0.1998
# Epoch: 044/050 | Batch 0200/0500 | Cost: 0.1464
# Epoch: 044/050 | Batch 0300/0500 | Cost: 0.2335
# Epoch: 044/050 | Batch 0400/0500 | Cost: 0.5416
# Epoch: 044/050 | Batch 0500/0500 | Cost: 0.8146
# epoch 44, loss 0.3537, train acc 89.408%, top_1 test acc 73.300%, top_5 test acc 92.790%
# EPOCH:  45 learning rate:  0.001
# Epoch: 045/050 | Batch 0100/0500 | Cost: 0.3497
# Epoch: 045/050 | Batch 0200/0500 | Cost: 0.3377
# Epoch: 045/050 | Batch 0300/0500 | Cost: 0.0741
# Epoch: 045/050 | Batch 0400/0500 | Cost: 0.3078
# Epoch: 045/050 | Batch 0500/0500 | Cost: 0.3763
# epoch 45, loss 0.3476, train acc 89.568%, top_1 test acc 73.000%, top_5 test acc 92.550%
# EPOCH:  46 learning rate:  0.001
# Epoch: 046/050 | Batch 0100/0500 | Cost: 0.6682
# Epoch: 046/050 | Batch 0200/0500 | Cost: 0.4105
# Epoch: 046/050 | Batch 0300/0500 | Cost: 0.2966
# Epoch: 046/050 | Batch 0400/0500 | Cost: 0.2002
# Epoch: 046/050 | Batch 0500/0500 | Cost: 0.2182
# epoch 46, loss 0.3377, train acc 89.910%, top_1 test acc 73.290%, top_5 test acc 92.860%
# EPOCH:  47 learning rate:  0.001
# Epoch: 047/050 | Batch 0100/0500 | Cost: 0.3883
# Epoch: 047/050 | Batch 0200/0500 | Cost: 0.4014
# Epoch: 047/050 | Batch 0300/0500 | Cost: 0.2105
# Epoch: 047/050 | Batch 0400/0500 | Cost: 0.5130
# Epoch: 047/050 | Batch 0500/0500 | Cost: 0.4323
# epoch 47, loss 0.3332, train acc 89.940%, top_1 test acc 73.160%, top_5 test acc 92.670%
# EPOCH:  48 learning rate:  0.001
# Epoch: 048/050 | Batch 0100/0500 | Cost: 0.4663
# Epoch: 048/050 | Batch 0200/0500 | Cost: 1.0484
# Epoch: 048/050 | Batch 0300/0500 | Cost: 0.5677
# Epoch: 048/050 | Batch 0400/0500 | Cost: 0.3638
# Epoch: 048/050 | Batch 0500/0500 | Cost: 0.2291
# epoch 48, loss 0.3271, train acc 90.262%, top_1 test acc 73.100%, top_5 test acc 92.780%
# EPOCH:  49 learning rate:  0.001
# Epoch: 049/050 | Batch 0100/0500 | Cost: 0.4925
# Epoch: 049/050 | Batch 0200/0500 | Cost: 0.1487
# Epoch: 049/050 | Batch 0300/0500 | Cost: 0.1105
# Epoch: 049/050 | Batch 0400/0500 | Cost: 0.2490
# Epoch: 049/050 | Batch 0500/0500 | Cost: 0.3268
# epoch 49, loss 0.3201, train acc 90.500%, top_1 test acc 73.000%, top_5 test acc 92.690%
# EPOCH:  50 learning rate:  0.001
# Epoch: 050/050 | Batch 0100/0500 | Cost: 0.6104
# Epoch: 050/050 | Batch 0200/0500 | Cost: 0.1580
# Epoch: 050/050 | Batch 0300/0500 | Cost: 0.2955
# Epoch: 050/050 | Batch 0400/0500 | Cost: 0.4656
# Epoch: 050/050 | Batch 0500/0500 | Cost: 0.2799
# epoch 50, loss 0.3190, train acc 90.296%, top_1 test acc 73.290%, top_5 test acc 92.610%
# Finished.

# %% [markdown]
# ## Plotting

# %%
# Record once every 100 iterations, and 10 workers need to communicate in each iteration
original_num = 1000
print("original communication number:", original_num)

TASGS_data = pd.read_csv("./result/"+"TASGS-res-cifar100-iter.csv")
SASG_data = pd.read_csv("./result/"+"SASG-res-cifar100-iter.csv")
LASG_data = pd.read_csv("./result/"+"LASG-res-cifar100-iter.csv")
sparse_data = pd.read_csv("./result/"+"Sparse-res-cifar100-iter.csv")
sgd_data = pd.read_csv("./result/"+"SGD-res-cifar100-iter.csv")

TASGS_skip = TASGS_data['Skip'].values.tolist()
SASG_skip = SASG_data['Skip'].values.tolist()
LASG_skip = LASG_data['Skip'].values.tolist()

comm_round_TASGS = []
comm_round_SASG = []
comm_round_LASG = []
comm_round_sparse = []
comm_round_dis = []

comm_bit_TASGS = []
comm_bit_SASG = []
comm_bit_LASG = []
comm_bit_sparse = []
comm_bit_dis = []

comm_num_TASGS, comm_num_SASG, comm_num_LASG, comm_num_sparse, comm_num_dis = 0, 0, 0, 0, 0
for i in range(len(TASGS_skip)):
    comm_num_TASGS += original_num
    comm_num_SASG += original_num
    comm_num_LASG += original_num
    comm_num_sparse += original_num
    comm_num_dis += original_num
    
    comm_round_TASGS.append(comm_num_TASGS - TASGS_skip[i])
    comm_round_SASG.append(comm_num_SASG - SASG_skip[i])
    comm_round_LASG.append(comm_num_LASG - LASG_skip[i])
    comm_round_sparse.append(comm_num_sparse)
    comm_round_dis.append(comm_num_dis)

font1 = {'weight': 'normal', 'size': 17}
font2 = {'weight': 'normal', 'size': 20}
plt.figure()
plt.rc('font', size=17)
plt.subplot(facecolor="whitesmoke")
plt.grid(axis="x", color='w', linestyle='-', which='major', linewidth=1.2)
plt.grid(axis="y", color='w', linestyle='-', which='both', linewidth=1.2)
plt.plot(comm_round_dis, sgd_data['test-acc'].values.tolist(), 'black', label='SGD', linewidth=2.5)
plt.plot(comm_round_sparse, sparse_data['test-acc'].values.tolist(), 'b', label='Sparse', linewidth=2.5)
plt.plot(comm_round_LASG, LASG_data['test-acc'].values.tolist(), 'g', label='LASG', linewidth=2.5)
plt.plot(comm_round_SASG, SASG_data['test-acc'].values.tolist(), 'r', label='SASG', linewidth=2.5)
plt.plot(comm_round_TASGS, TASGS_data['test-acc'].values.tolist(), 'c', label='GSASG', linewidth=2.5)

ax = plt.gca()
xmajorLocator = MultipleLocator(50000)  # major
ax.xaxis.set_major_locator(xmajorLocator)
xminorLocator = MultipleLocator(25000)  # minor
ax.xaxis.set_minor_locator(xminorLocator)
ax.ticklabel_format(axis='x', style='scientific', scilimits=(0, 0))
plt.xlabel('Communication Round', font2)
plt.ylim(30, 95)
ymajorLocator = MultipleLocator(15)  # major
ax.yaxis.set_major_locator(ymajorLocator)
yminorLocator = MultipleLocator(15)  # minor
ax.yaxis.set_minor_locator(yminorLocator)
plt.ylabel('Test Accuracy', font2)
legend = plt.legend(prop=font1)
plt.subplots_adjust(left=0.13, right=0.95, bottom=0.15, top=0.95)
plt.savefig("./result/"+"test_res_cifar100.png", dpi=600)
plt.show()


plt.figure()
plt.rc('font', size=17)
plt.subplot(facecolor="whitesmoke")
plt.grid(axis="x", color='w', linestyle='-', which='major', linewidth=1.2)
plt.grid(axis="y", color='w', linestyle='-', which='major', linewidth=1.2)
plt.plot(comm_round_dis, sgd_data['Loss'].values.tolist(), 'black', label='SGD', linewidth=2.5)
plt.plot(comm_round_sparse, sparse_data['Loss'].values.tolist(), 'b', label='Sparse', linewidth=2.5)
plt.plot(comm_round_LASG, LASG_data['Loss'].values.tolist(), 'g', label='LASG', linewidth=2.5)
plt.plot(comm_round_SASG, SASG_data['Loss'].values.tolist(), 'r', label='SASG', linewidth=2.5)
plt.plot(comm_round_TASGS, TASGS_data['Loss'].values.tolist(), 'c', label='GSASG', linewidth=2.5)

ax = plt.gca()
xmajorLocator = MultipleLocator(50000)  # major
ax.xaxis.set_major_locator(xmajorLocator)
xminorLocator = MultipleLocator(25000)  # minor
ax.xaxis.set_minor_locator(xminorLocator)
ax.ticklabel_format(axis='x', style='scientific', scilimits=(0, 0))
plt.xlabel('Communication Round', font2)
plt.yscale('log')
plt.ylabel('Loss', font2)
plt.ylim(0.23, 4.99)
ax.set_yticks((0.3, 1, 3))
ax.set_yticklabels(['$3 x 10^{-1}$', '$10^{0}$', '$3 x 10^{0}$'], fontsize=17)
legend = plt.legend(prop=font1)
plt.subplots_adjust(left=0.16, right=0.95, bottom=0.15, top=0.95)
plt.savefig("./result/"+"loss_res_cifar100.png", dpi=600)
plt.show()
# Out:
# original communication number: 1000

# %%
# Record once every 100 iterations, and 10 workers need to communicate in each iteration
original_num = 1000
print("original communication number:", original_num)

TASGS_data = pd.read_csv("./result/"+"TASGS-res-cifar100-iter-new.csv")
SASG_data = pd.read_csv("./result/"+"SASG-res-cifar100-iter.csv")
LASG_data = pd.read_csv("./result/"+"LASG-res-cifar100-iter.csv")
sparse_data = pd.read_csv("./result/"+"Sparse-res-cifar100-iter.csv")
sgd_data = pd.read_csv("./result/"+"SGD-res-cifar100-iter.csv")

TASGS_skip = TASGS_data['Skip'].values.tolist()
SASG_skip = SASG_data['Skip'].values.tolist()
LASG_skip = LASG_data['Skip'].values.tolist()

comm_round_TASGS = []
comm_round_SASG = []
comm_round_LASG = []
comm_round_sparse = []
comm_round_dis = []

comm_bit_TASGS = []
comm_bit_SASG = []
comm_bit_LASG = []
comm_bit_sparse = []
comm_bit_dis = []

comm_num_TASGS, comm_num_SASG, comm_num_LASG, comm_num_sparse, comm_num_dis = 0, 0, 0, 0, 0
for i in range(len(TASGS_skip)):
    comm_num_TASGS += original_num
    comm_num_SASG += original_num
    comm_num_LASG += original_num
    comm_num_sparse += original_num
    comm_num_dis += original_num
    
    comm_round_TASGS.append(comm_num_TASGS - TASGS_skip[i])
    comm_round_SASG.append(comm_num_SASG - SASG_skip[i])
    comm_round_LASG.append(comm_num_LASG - LASG_skip[i])
    comm_round_sparse.append(comm_num_sparse)
    comm_round_dis.append(comm_num_dis)

font1 = {'weight': 'normal', 'size': 17}
font2 = {'weight': 'normal', 'size': 20}
plt.figure()
plt.rc('font', size=17)
plt.subplot(facecolor="whitesmoke")
plt.grid(axis="x", color='w', linestyle='-', which='major', linewidth=1.2)
plt.grid(axis="y", color='w', linestyle='-', which='both', linewidth=1.2)
plt.plot(comm_round_dis, sgd_data['test-acc'].values.tolist(), 'black', label='SGD', linewidth=2.5)
plt.plot(comm_round_sparse, sparse_data['test-acc'].values.tolist(), 'b', label='Sparse', linewidth=2.5)
plt.plot(comm_round_LASG, LASG_data['test-acc'].values.tolist(), 'g', label='LASG', linewidth=2.5)
plt.plot(comm_round_SASG, SASG_data['test-acc'].values.tolist(), 'r', label='SASG', linewidth=2.5)
plt.plot(comm_round_TASGS, TASGS_data['test-acc'].values.tolist(), 'c', label='GSASG', linewidth=2.5)

ax = plt.gca()
xmajorLocator = MultipleLocator(50000)  # major
ax.xaxis.set_major_locator(xmajorLocator)
xminorLocator = MultipleLocator(25000)  # minor
ax.xaxis.set_minor_locator(xminorLocator)
ax.ticklabel_format(axis='x', style='scientific', scilimits=(0, 0))
plt.xlabel('Communication Round', font2)
plt.ylim(30, 95)
ymajorLocator = MultipleLocator(15)  # major
ax.yaxis.set_major_locator(ymajorLocator)
yminorLocator = MultipleLocator(15)  # minor
ax.yaxis.set_minor_locator(yminorLocator)
plt.ylabel('Test Accuracy', font2)
legend = plt.legend(prop=font1)
plt.subplots_adjust(left=0.13, right=0.95, bottom=0.15, top=0.95)
plt.savefig("./result/"+"test_res_cifar100.png", dpi=600)
plt.show()


plt.figure()
plt.rc('font', size=17)
plt.subplot(facecolor="whitesmoke")
plt.grid(axis="x", color='w', linestyle='-', which='major', linewidth=1.2)
plt.grid(axis="y", color='w', linestyle='-', which='major', linewidth=1.2)
plt.plot(comm_round_dis, sgd_data['Loss'].values.tolist(), 'black', label='SGD', linewidth=2.5)
plt.plot(comm_round_sparse, sparse_data['Loss'].values.tolist(), 'b', label='Sparse', linewidth=2.5)
plt.plot(comm_round_LASG, LASG_data['Loss'].values.tolist(), 'g', label='LASG', linewidth=2.5)
plt.plot(comm_round_SASG, SASG_data['Loss'].values.tolist(), 'r', label='SASG', linewidth=2.5)
plt.plot(comm_round_TASGS, TASGS_data['Loss'].values.tolist(), 'c', label='GSASG', linewidth=2.5)

ax = plt.gca()
xmajorLocator = MultipleLocator(50000)  # major
ax.xaxis.set_major_locator(xmajorLocator)
xminorLocator = MultipleLocator(25000)  # minor
ax.xaxis.set_minor_locator(xminorLocator)
ax.ticklabel_format(axis='x', style='scientific', scilimits=(0, 0))
plt.xlabel('Communication Round', font2)
plt.yscale('log')
plt.ylabel('Loss', font2)
plt.ylim(0.23, 4.99)
ax.set_yticks((0.3, 1, 3))
ax.set_yticklabels(['$3 x 10^{-1}$', '$10^{0}$', '$3 x 10^{0}$'], fontsize=17)
legend = plt.legend(prop=font1)
plt.subplots_adjust(left=0.16, right=0.95, bottom=0.15, top=0.95)
plt.savefig("./result/"+"loss_res_cifar100.png", dpi=600)
plt.show()
# Out:
# original communication number: 1000
